# %% [markdown]
# # [【SOTA】マイナビ × SIGNATE Student Cup 2019: 賃貸物件の家賃予測](https://signate.jp/competitions/264)

# %% [markdown]
# ## 1. データ読み込み

# %%
import pandas as pd
import numpy as np
import pathlib
import os

# 学習データ、テストデータの読み込み
train_path = pathlib.Path("./DATA/train.csv")
test_path = pathlib.Path("./DATA/test.csv")

train_data = pd.read_csv(train_path)
test_data = pd.read_csv(test_path)

# %%
test_data.head()
# Out:
#       id                所在地  \
# 0  31471   東京都世田谷区深沢５丁目1-27
# 1  31472    東京都目黒区八雲１丁目11-8
# 2  31473  東京都豊島区池袋本町２丁目22-2
# 3  31474        東京都杉並区和泉１丁目
# 4  31475       東京都杉並区堀ノ内２丁目
#
#                                                 アクセス   間取り     築年数  方角  \
# 0  東急大井町線\t等々力駅\t徒歩15分\t\t東急田園都市線\t桜新町駅\t徒歩24分\t\...  2LDK  49年0ヶ月   南
# 1  東急東横線\t都立大学駅\t徒歩6分\t\t東急東横線\t自由が丘駅\t徒歩17分\t\t東...    1R   0年2ヶ月  南東
# 2  東武東上線\t北池袋駅\t徒歩10分\t\t埼京線\t板橋駅\t徒歩16分\t\t山手線\t...    1K  23年4ヶ月  南東
# 3  丸ノ内線(中野坂上－方南町)\t方南町駅\t徒歩10分\t\t京王線\t代田橋駅\t徒歩8分...    1K  36年2ヶ月  南東
# 4  丸ノ内線(中野坂上－方南町)\t方南町駅\t徒歩12分\t\t丸ノ内線(池袋－荻窪)\t新高...  2LDK  45年4ヶ月   南
#
#         面積     所在階                                             バス・トイレ  \
# 0  50.22m2  8階／8階建  専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t追焚機能／\t温水洗浄便座／...
# 1  20.88m2  3階／4階建  専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t浴室乾燥機\t／\t温水洗浄...
# 2  26.93m2  1階／4階建             専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t温水洗浄便座
# 3  23.57m2  1階／2階建                                               シャワー
# 4     50m2  4階／4階建                             専用バス／\t専用トイレ／\tバス・トイレ別
#
#                                        キッチン  \
# 0  ガスコンロ／\tコンロ3口／\tシステムキッチン\t／\t給湯／\tL字キッチン
# 1           ガスコンロ／\tコンロ2口／\tシステムキッチン\t／\t給湯
# 2                                ガスコンロ／\t給湯
# 3                                ガスコンロ／\t給湯
# 4                         コンロ設置可（口数不明）／\t給湯
#
#                                         放送・通信  \
# 0                                   インターネット対応
# 1  インターネット対応／\tCSアンテナ／\tBSアンテナ／\tインターネット使用料無料
# 2                   インターネット対応／\t光ファイバー／\tCATV
# 3                                         NaN
# 4                                   インターネット対応
#
#                                                 室内設備  \
# 0  エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\tエレベーター\t公営水...
# 1  エアコン付\tシューズボックス／\tフローリング／\t室内洗濯機置場\t公営水道／\t下水／...
# 2  エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t2面採光／\t室内洗濯...
# 3  エアコン付\tシューズボックス／\t2面採光／\t室外洗濯機置場\t公営水道／\t下水／\t...
# 4  冷房／\tエアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t室内洗濯機置...
#
#                                                  駐車場  \
# 0                         駐輪場\t空有\t駐車場\t無\tバイク置き場\t無
# 1    駐車場\t近隣\t34,000円(税込)\t距離200m\t駐輪場\t無\tバイク置き場\t無
# 2  駐車場\t空有\t5,000円(税込)\t(敷金あり\t1ヶ月)\t駐輪場\t空有\tバイク...
# 3                                        駐輪場\t空有\t0円
# 4                           駐車場\t近隣\t22,600円\t距離177m
#
#                                                 周辺環境          建物構造 契約期間
# 0  【コンビニ】 74m\t【スーパー】 215m\t【病院】 313m\t【小学校】 219m...           鉄骨造  NaN
# 1  【スーパー】 128m\t【スーパー】 313m\t【コンビニ】 374m\t【コンビニ】 ...  RC（鉄筋コンクリート）  2年間
# 2  【スーパー】 529m\t【スーパー】 810m\t【コンビニ】 316m\t【コンビニ】 ...           鉄骨造  2年間
# 3  【スーパー】 286m\t【スーパー】 702m\t【コンビニ】 489m\t【コンビニ】 ...            木造  2年間
# 4  【コンビニ】 312m\t【コンビニ】 436m\t【スーパー】 902m\t【コンビニ】 ...  RC（鉄筋コンクリート）  2年間

# %% [markdown]
# ## 2. 前処理

# %% [markdown]
# ### 2.1. データ選択

# %%
train_data_1 = train_data[["id", "所在地", "賃料", "間取り", "築年数", "面積", "所在階", "建物構造"]]
test_data_1 = test_data[["id", "所在地", "間取り", "築年数", "面積", "所在階", "建物構造"]]

# %% [markdown]
# ### 2.2. 間取りの数値化

# %%
# 間取りにlabel encodingを適用
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(pd.concat([train_data_1["間取り"],test_data_1["間取り"]]))

train_data_1["間取りID"] = le.transform(train_data_1["間取り"])
test_data_1["間取りID"] = le.transform(test_data_1["間取り"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### 2.3. 面積の数値化

# %%
# 面積のカラムタイトルを面積[m2]に置換
train_data_1 = train_data_1.rename(columns={"面積": "面積m2"})
test_data_1 = test_data_1.rename(columns={"面積": "面積m2"})

# %%
# カラムタイトル面積[m2]の要素からm2を削除
train_data_1['面積m2'] = train_data_1['面積m2'].str.replace('m2', '').astype(float)
test_data_1['面積m2'] = test_data_1['面積m2'].str.replace('m2', '').astype(float)

# %% [markdown]
# ### 2.4. 所在階の数値化

# %%
# 所在階の中身を"／"で2つの列に分割
train_data_1 = pd.concat([train_data_1, train_data_1['所在階'].str.split('／', expand=True)], axis=1)
test_data_1 = pd.concat([test_data_1, test_data_1['所在階'].str.split('／', expand=True)], axis=1)

# %%
# 分割した所在階のカラム名変更　0:所在、1:階層
train_data_1 = train_data_1.rename(columns={0:"所在", 1:"階層"})
test_data_1 = test_data_1.rename(columns={0:"所在", 1:"階層"})

# %%
# 所在と階層の要素を整形
train_data_1['所在'] = train_data_1['所在'].str.replace('階', '')
train_data_1['所在'] = train_data_1['所在'].str.replace('建', '')
train_data_1['所在'] = train_data_1['所在'].str.replace('地下', '-')
train_data_1['所在'] = train_data_1['所在'].str.replace('\（.*\）', '', regex=True)
train_data_1['階層'] = train_data_1['階層'].str.replace('階建', '')
train_data_1['階層'] = train_data_1['階層'].str.replace('\（.*\）', '', regex=True)
train_data_1['所在'] = train_data_1['所在'].replace('', np.nan)

test_data_1['所在'] = test_data_1['所在'].str.replace('階', '')
test_data_1['所在'] = test_data_1['所在'].str.replace('建', '')
test_data_1['所在'] = test_data_1['所在'].str.replace('地下', '-')
test_data_1['所在'] = test_data_1['所在'].str.replace('\（.*\）', '', regex=True)
test_data_1['階層'] = test_data_1['階層'].str.replace('階建', '')
test_data_1['階層'] = test_data_1['階層'].str.replace('\（.*\）', '', regex=True)
test_data_1['所在'] = test_data_1['所在'].replace('', np.nan)

# %%
# # "階層"がNoneの箇所を"所在"の値で埋める
# train_data_1['階層'].fillna(train_data_1['所在'], inplace=True)
# test_data_1['階層'].fillna(test_data_1['所在'], inplace=True)

# %%
# 所在と階層の要素をfloat型に変換する
train_data_1['所在'] = train_data_1['所在'].astype(float)
train_data_1['階層'] = train_data_1['階層'].astype(float)

test_data_1['所在'] = test_data_1['所在'].astype(float)
test_data_1['階層'] = test_data_1['階層'].astype(float)

# %%
# 所在階のカラムを削除
train_data_1 = train_data_1.drop('所在階', axis=1)
test_data_1 = test_data_1.drop('所在階', axis=1)

# %%
# # 所在のNaNを埋める
# train_data_1.loc[train_data_1["所在"].isnull(), "所在"] = train_data_1["階層"]
# test_data_1.loc[test_data_1["所在"].isnull(), "所在"] = test_data_1["階層"]

# %%
# # 所在も階層も空欄のデータは間取りと面積の近いデータで埋める
# print(test_data_1[(test_data_1["間取りID"] == 21) & (test_data_1["面積m2"] > 90) & (test_data_1["面積m2"] < 95)].mean())
# test_data_1.loc[test_data_1["id"]==40675, "所在"] = float(6)
# test_data_1.loc[test_data_1["id"]==40675, "階層"] = float(9)

# %% [markdown]
# ### 2.5. 築年数の数値化

# %%
# 新築の場合は全て0にする
train_data_1.loc[train_data_1["築年数"]=="新築", "築年数"] = float(0)
test_data_1.loc[test_data_1["築年数"]=="新築", "築年数"] = float(0)

# %%
# 築年数を数値に変換する
train_data_1 = pd.concat([train_data_1, train_data_1['築年数'].str.split('年', expand=True)], axis=1)
test_data_1 = pd.concat([test_data_1, test_data_1['築年数'].str.split('年', expand=True)], axis=1)

# %%
# ヶ月を消す
train_data_1[1] = train_data_1[1].str.replace('ヶ月', '')
test_data_1[1] = test_data_1[1].str.replace('ヶ月', '')

# %%
# 築年数をfloat変換
train_data_1["築年数"] = train_data_1[0].astype(float) + (train_data_1[1].astype(float) / float(10))
test_data_1["築年数"] = test_data_1[0].astype(float) + (test_data_1[1].astype(float) / float(10))

# %%
test_data_1.head()
# Out:
#       id                所在地   間取り   築年数   面積m2          建物構造  間取りID   所在   階層  \
# 0  31471   東京都世田谷区深沢５丁目1-27  2LDK  49.0  50.22           鉄骨造     14  8.0  8.0
# 1  31472    東京都目黒区八雲１丁目11-8    1R   0.2  20.88  RC（鉄筋コンクリート）      9  3.0  4.0
# 2  31473  東京都豊島区池袋本町２丁目22-2    1K  23.4  26.93           鉄骨造      3  1.0  4.0
# 3  31474        東京都杉並区和泉１丁目    1K  36.2  23.57            木造      3  1.0  2.0
# 4  31475       東京都杉並区堀ノ内２丁目  2LDK  45.4  50.00  RC（鉄筋コンクリート）     14  4.0  4.0
#
#     0  1
# 0  49  0
# 1   0  2
# 2  23  4
# 3  36  2
# 4  45  4

# %%
print(test_data_1[test_data_1["築年数"].isnull()])
# Out:
#           id               所在地       間取り  築年数   面積m2          建物構造  間取りID  \
# 77     31548      東京都大田区東矢口２丁目  1K+S(納戸)  NaN  23.80           鉄骨造      4
# 108    31579  東京都世田谷区上馬２丁目26-8        1K  NaN  26.44  RC（鉄筋コンクリート）      3
# 112    31583       東京都台東区台東２丁目      1LDK  NaN  41.65           鉄骨造      5
# 156    31627  東京都品川区南大井４丁目20-5        1R  NaN  20.56  RC（鉄筋コンクリート）      9
# 162    31633     東京都江東区扇橋２丁目23        1K  NaN  25.34  RC（鉄筋コンクリート）      3
# ...      ...               ...       ...  ...    ...           ...    ...
# 31141  62612  東京都世田谷区桜丘４丁目15-9      2LDK  NaN  60.81            木造     14
# 31176  62647   東京都江戸川区中葛西８丁目22      1LDK  NaN  40.06  RC（鉄筋コンクリート）      5
# 31181  62652       東京都新宿区原町３丁目      1LDK  NaN  40.26           鉄骨造      5
# 31182  62653       東京都新宿区原町３丁目      2LDK  NaN  54.75           鉄骨造     14
# 31212  62683       東京都新宿区原町３丁目      1LDK  NaN  40.79           鉄骨造      5
#
#         所在    階層    0    1
# 77     2.0   3.0  NaN  NaN
# 108    7.0  13.0  NaN  NaN
# 112    3.0  10.0  NaN  NaN
# 156    3.0  12.0  NaN  NaN
# 162    1.0   8.0  NaN  NaN
# ...    ...   ...  ...  ...
# 31141  2.0   2.0  NaN  NaN
# 31176  3.0  10.0  NaN  NaN
# 31181  2.0   3.0  NaN  NaN
# 31182  1.0   3.0  NaN  NaN
# 31212  2.0   3.0  NaN  NaN
#
# [850 rows x 11 columns]

# %%
# 0と1の列を消す
train_data_1 = train_data_1.drop(0, axis=1)
train_data_1 = train_data_1.drop(1, axis=1)

test_data_1 = test_data_1.drop(0, axis=1)
test_data_1 = test_data_1.drop(1, axis=1)

# %% [markdown]
# ### 2.6. 緯度経度情報の追加

# %% [markdown]
# #### [このサイト](https://ktgis.net/gcode/geocoding.html)を利用する

# %%
# IDと住所をファイル出力
train_coordinate = train_data[["id", "所在地"]]
test_coordinate = test_data[["id", "所在地"]]

train_coordinate.to_csv("train_coordinate.csv", header=False, index=False)
test_coordinate.to_csv("test_coordinate.csv", header=False, index=False)

# %%
# 緯度、経度情報の読み込み(id, 所在地, 経度, 緯度)
train_coordinate_addvalue = pd.read_excel("train_coordinate_addvalue.xlsx")
test_coordinate_addvalue = pd.read_excel("test_coordinate_addvalue.xlsx")

# %%
train_data_1 = pd.merge(train_data_1, train_coordinate_addvalue[["id", "経度", "緯度"]], on='id')
test_data_1 = pd.merge(test_data_1, test_coordinate_addvalue[["id", "経度", "緯度"]], on='id')

# %% [markdown]
# ### 2.7. 部屋数の追加

# %%
# 部屋数のマージ
number_of_rooms = pd.read_excel("number_of_rooms.xlsx")
train_data_1 = pd.merge(train_data_1, number_of_rooms[["間取り", "部屋数"]], on='間取り')
test_data_1 = pd.merge(test_data_1, number_of_rooms[["間取り", "部屋数"]], on='間取り')

# %%
# インデックスの振り直し
train_data_1 = train_data_1.sort_values("id")
train_data_1 = train_data_1.reset_index(drop=True)

test_data_1 = test_data_1.sort_values("id")
test_data_1 = test_data_1.reset_index(drop=True)

# %% [markdown]
# ### 2.8. 1部屋当たりの面積追加

# %%
# 面積と部屋数から1部屋当たりの面積を算出
train_data_1["1部屋当たり面積m2"] = (train_data_1["面積m2"] / train_data_1["部屋数"]).astype(float)
test_data_1["1部屋当たり面積m2"] = (test_data_1["面積m2"] / test_data_1["部屋数"]).astype(float)

# %%
# 間取りと間取りIDは削除する
train_data_1 = train_data_1.drop('間取り', axis=1)
test_data_1 = test_data_1.drop('間取り', axis=1)

# train_data_1 = train_data_1.drop('間取りID', axis=1)
# test_data_1 = test_data_1.drop('間取りID', axis=1)

# %% [markdown]
# #### 2.9. 建物の高さ率を追加(高さ率=所在/階層)

# %%
# 高さ率の算出
train_data_1["高さ率"] = (train_data_1["所在"] / train_data_1["階層"]).astype(float)
test_data_1["高さ率"] = (test_data_1["所在"] / test_data_1["階層"]).astype(float)

# %% [markdown]
# ### 2.10. 建物構造の数値化

# %%
train_data_1["建物構造"].value_counts()
# Out:
# RC（鉄筋コンクリート）                   17505
# 木造                              5512
# 鉄骨造                             3726
# SRC（鉄骨鉄筋コンクリート）                 2429
# 軽量鉄骨                            1812
# ALC（軽量気泡コンクリート）                  297
# その他                              136
# PC（プレキャスト・コンクリート（鉄筋コンクリート））       46
# HPC（プレキャスト・コンクリート（重量鉄骨））           4
# ブロック                               3
# Name: 建物構造, dtype: int64

# %%
# 建物構造にlabel encodingを適用
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(pd.concat([train_data_1["建物構造"],test_data_1["建物構造"]]))

train_data_1["建物構造ID"] = le.transform(train_data_1["建物構造"])
test_data_1["建物構造ID"] = le.transform(test_data_1["建物構造"])

# %%
test_data_1.head()
# Out:
#       id                所在地   築年数   面積m2          建物構造  間取りID   所在   階層  \
# 0  31471   東京都世田谷区深沢５丁目1-27  49.0  50.22           鉄骨造     14  8.0  8.0
# 1  31472    東京都目黒区八雲１丁目11-8   0.2  20.88  RC（鉄筋コンクリート）      9  3.0  4.0
# 2  31473  東京都豊島区池袋本町２丁目22-2  23.4  26.93           鉄骨造      3  1.0  4.0
# 3  31474        東京都杉並区和泉１丁目  36.2  23.57            木造      3  1.0  2.0
# 4  31475       東京都杉並区堀ノ内２丁目  45.4  50.00  RC（鉄筋コンクリート）     14  4.0  4.0
#
#            経度         緯度  部屋数  1部屋当たり面積m2   高さ率  建物構造ID
# 0  139.652762  35.617708  3.5   14.348571  1.00      10
# 1  139.672871  35.617709  1.0   20.880000  0.75       3
# 2  139.709049  35.741996  1.0   26.930000  0.25      10
# 3  139.658270  35.673602  1.0   23.570000  0.50       7
# 4  139.650468  35.689411  3.5   14.285714  1.00       3

# %%
# 不要になった建物構造カラムを削除する
train_data_1 = train_data_1.drop('建物構造', axis=1)
test_data_1 = test_data_1.drop('建物構造', axis=1)

# %% [markdown]
# ### 2.11. 新規カラムに「賃料/面積」を追加

# %%
train_data_1["賃料/面積"] = train_data_1["賃料"] / train_data_1["面積m2"]

# %%
train_data_1.head()
# Out:
#    id                所在地      賃料   築年数   面積m2  間取りID    所在    階層          経度  \
# 0   1        東京都北区滝野川３丁目   75000   9.9  20.01      3   1.0  12.0  139.727873
# 1   2        東京都中央区月島３丁目   76000  45.0  16.50      9   5.0  10.0  139.780485
# 2   3        東京都渋谷区笹塚２丁目  110000   8.6  22.05      3  12.0  15.0  139.667375
# 3   4  東京都杉並区高円寺南２丁目23-2  150000  29.4  60.48     14   3.0   4.0  139.648495
# 4   5     東京都葛飾区金町３丁目7-2   74000  31.7  39.66     10   1.0   2.0  139.872315
#
#           緯度  部屋数  1部屋当たり面積m2       高さ率  建物構造ID        賃料/面積
# 0  35.747759  1.0       20.01  0.083333       3  3748.125937
# 1  35.662406  1.0       16.50  0.500000      10  4606.060606
# 2  35.675358  1.0       22.05  0.800000       3  4988.662132
# 3  35.700193  3.5       17.28  0.750000       3  2480.158730
# 4  35.766413  3.0       13.22  0.500000       7  1865.859808

# %% [markdown]
# ### 2.12. 東京23区の地域ごとに、住宅地の平均地価情報を追加

# %%
# 区の情報の確認(23区だけだった)
# sample = train_data["所在地"].str.extract("東京都(.+区)", expand=True)
# sample.value_counts()

# %%
print(len(train_data_1))
print(len(test_data_1))
# Out:
# 31470
# 31262

# %%
# 訓練データとテストデータに、エリア情報を追加
train_data_1["エリア"] = ""
test_data_1["エリア"] = ""
train_data_1["エリア"] = train_data_1["所在地"].str.extract("東京都((.+区.+?)[０-９]|(.+区.+?)[0-9]|(.+区.+))", expand=True)
test_data_1["エリア"] = test_data_1["所在地"].str.extract("東京都((.+区.+?)[０-９]|(.+区.+?)[0-9]|(.+区.+))", expand=True)

# %%
print(len(train_data_1))
print(len(test_data_1))
# Out:
# 31470
# 31262

# %%
# 一部エリア情報に数値が残ってしまうので、消す
train_data_1["エリア"] = train_data_1["エリア"].str.replace("[０-９]|[0-9]", "")
train_data_1["エリア"] = train_data_1["エリア"].str.replace("一丁目", "")
train_data_1["エリア"] = train_data_1["エリア"].str.replace("-", "")

test_data_1["エリア"] = test_data_1["エリア"].str.replace("[０-９]|[0-9]", "")
test_data_1["エリア"] = test_data_1["エリア"].str.replace("一丁目", "")
test_data_1["エリア"] = test_data_1["エリア"].str.replace("二丁目", "")
test_data_1["エリア"] = test_data_1["エリア"].str.replace("四丁目", "")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
print(len(train_data_1))
print(len(test_data_1))
# Out:
# 31470
# 31262

# %%
# 坪単価情報の読込～結合
wards_value = pd.read_excel("23区_地域毎_坪単価.xlsx")
train_data_1 = pd.merge(train_data_1, wards_value, on="エリア", how="left")
test_data_1 = pd.merge(test_data_1, wards_value, on="エリア", how="left")
train_data_1 = train_data_1.sort_values("id")
test_data_1 = test_data_1.sort_values("id")

# %%
# 地価の抜けデータを平均値で補間
# 江東区
train_data_1.loc[train_data_1["id"]==2767, "平均坪単価（万円）"] = 206.6
train_data_1.loc[train_data_1["id"]==7559, "平均坪単価（万円）"] = 206.6
# 港区
train_data_1.loc[train_data_1["id"]==17654, "平均坪単価（万円）"] = 1321.4

# %%
print(len(train_data_1))
print(len(test_data_1))
# Out:
# 31470
# 31262

# %%
print(train_data_1[train_data_1["平均坪単価（万円）"].isnull()])
print(test_data_1[test_data_1["平均坪単価（万円）"].isnull()])
# Out:
# Empty DataFrame
# Columns: [id, 所在地, 賃料, 築年数, 面積m2, 間取りID, 所在, 階層, 経度, 緯度, 部屋数, 1部屋当たり面積m2, 高さ率, 建物構造ID, 賃料/面積, エリア, 区, 地名, 平均坪単価（万円）, Unnamed: 4]
# Index: []
# Empty DataFrame
# Columns: [id, 所在地, 築年数, 面積m2, 間取りID, 所在, 階層, 経度, 緯度, 部屋数, 1部屋当たり面積m2, 高さ率, 建物構造ID, エリア, 区, 地名, 平均坪単価（万円）, Unnamed: 4]
# Index: []

# %%
test_data_1
# Out:
#           id                所在地   築年数   面積m2  間取りID    所在    階層          経度  \
# 0      31471   東京都世田谷区深沢５丁目1-27  49.0  50.22     14   8.0   8.0  139.652762
# 1      31472    東京都目黒区八雲１丁目11-8   0.2  20.88      9   3.0   4.0  139.672871
# 2      31473  東京都豊島区池袋本町２丁目22-2  23.4  26.93      3   1.0   4.0  139.709049
# 3      31474        東京都杉並区和泉１丁目  36.2  23.57      3   1.0   2.0  139.658270
# 4      31475       東京都杉並区堀ノ内２丁目  45.4  50.00     14   4.0   4.0  139.650468
# ...      ...                ...   ...    ...    ...   ...   ...         ...
# 31257  62728       東京都豊島区上池袋４丁目   0.1  25.66      3   6.0   8.0  139.718979
# 31258  62729      東京都千代田区岩本町２丁目  15.6  22.71      9   8.0  15.0  139.776177
# 31259  62730   東京都中野区江古田３丁目14-3   1.0  45.76      5  10.0  14.0  139.667395
# 31260  62731         東京都千代田区二番町  15.4  55.20      3  14.0  14.0  139.734508
# 31261  62732       東京都大田区南馬込６丁目  16.3  21.18      3   5.0   5.0  139.708991
#
#               緯度  部屋数  1部屋当たり面積m2       高さ率  建物構造ID      エリア     区    地名  \
# 0      35.617708  3.5   14.348571  1.000000      10   世田谷区深沢  世田谷区    深沢
# 1      35.617709  1.0   20.880000  0.750000       3    目黒区八雲   目黒区    八雲
# 2      35.741996  1.0   26.930000  0.250000      10  豊島区池袋本町   豊島区  池袋本町
# 3      35.673602  1.0   23.570000  0.500000       7    杉並区和泉   杉並区    和泉
# 4      35.689411  3.5   14.285714  1.000000       3   杉並区堀ノ内   杉並区   堀ノ内
# ...          ...  ...         ...       ...     ...      ...   ...   ...
# 31257  35.741285  1.0   25.660000  0.750000       3   豊島区上池袋   豊島区   上池袋
# 31258  35.693717  1.0   22.710000  0.533333       3  千代田区岩本町  千代田区   岩本町
# 31259  35.727602  2.5   18.304000  0.714286       3   中野区江古田   中野区   江古田
# 31260  35.686078  1.0   55.200000  1.000000       4  千代田区二番町  千代田区   二番町
# 31261  35.583653  1.0   21.180000  1.000000       3   大田区南馬込   大田区   南馬込
#
#        平均坪単価（万円）  Unnamed: 4
# 0          208.0         NaN
# 1          273.0         NaN
# 2          186.0         NaN
# 3          184.0         NaN
# 4          145.0         NaN
# ...          ...         ...
# 31257      190.0         NaN
# 31258      447.0         NaN
# 31259      167.0         NaN
# 31260      628.0         NaN
# 31261      175.0         NaN
#
# [31262 rows x 18 columns]

# %%
# 不要なカラムを削除する
train_data_1 = train_data_1.drop(["所在地", "エリア", "区", "地名"], axis=1)
test_data_1 = test_data_1.drop(["所在地", "エリア", "区", "地名"], axis=1)

# %% [markdown]
# ### 2.13. 重複物件の抽出・削除

# %%
# 重複確認用のデータ出力
# train_duplicate = pd.concat([train_data[["id", "賃料", "所在地"]], train_data_1[["間取りID", "面積m2", "所在", "階層"]]], axis=1)
# test_duplicate = pd.concat([test_data[["id", "所在地"]], test_data_1[["間取りID", "面積m2", "所在", "階層"]]], axis=1)

# %%
# 結果の出力
# train_duplicate.to_excel("train_duplicate.xlsx", header=True, index=False)
# test_duplicate.to_excel("test_duplicate.xlsx", header=True, index=False)

# %%
# 重複対象のデータ読み込み
train_duplicate_flag = pd.read_excel("train_duplicate_flag.xlsx")
test_duplicate_flag = pd.read_excel("test_duplicate_flag.xlsx")

# %%
# データ数のチェック
print("Train:", len(train_data_1), "-", len(train_duplicate_flag), "=", len(train_data_1)-len(train_duplicate_flag))
print("Test:", len(test_data_1), "-", len(test_duplicate_flag), "=", len(test_data_1)-len(test_duplicate_flag))
# Out:
# Train: 31470 - 31470 = 0
# Test: 31262 - 31262 = 0

# %%
# 重複フラグを結合
train_data_1 = pd.merge(train_data_1, train_duplicate_flag, on="id")
train_data_1 = train_data_1.rename(columns={"賃料_x":"賃料"})
train_data_1 = train_data_1.drop('賃料_y', axis=1)

test_data_1 = pd.merge(test_data_1, test_duplicate_flag, on="id")

# %%
# testデータからのみ、flag=1.0の列を削除
print("【削除前】", "train:", len(train_data_1), ", ", "test:", len(test_data_1))
#train_data_1 = train_data_1.loc[train_data_1["flag"] != 1.0]
test_data_1 = test_data_1.loc[test_data_1["flag"] != 1.0]
print("【削除後】", "train:", len(train_data_1), ", ", "test:", len(test_data_1))
# Out:
# 【削除前】 train: 31470 ,  test: 31262
# 【削除後】 train: 31470 ,  test: 24812

# %% [markdown]
# ## 3. データチェック

# %%
train_data_1.isnull().sum()
# Out:
# id                0
# 賃料                0
# 築年数             889
# 面積m2              0
# 間取りID             0
# 所在              120
# 階層              594
# 経度                0
# 緯度                0
# 部屋数               0
# 1部屋当たり面積m2        0
# 高さ率             714
# 建物構造ID            0
# 賃料/面積             0
# 平均坪単価（万円）         0
# Unnamed: 4    31470
# flag          25975
# dtype: int64

# %%
test_data_1.isnull().sum()
# Out:
# id                0
# 築年数             675
# 面積m2              0
# 間取りID             0
# 所在              102
# 階層              476
# 経度                0
# 緯度                0
# 部屋数               0
# 1部屋当たり面積m2        0
# 高さ率             577
# 建物構造ID            0
# 平均坪単価（万円）         0
# Unnamed: 4    24812
# flag          24812
# dtype: int64

# %%
len(train_data_1)
# Out:
# 31470

# %%
len(train_data)
# Out:
# 31470

# %%
len(test_data_1)
# Out:
# 24812

# %%
len(test_data)
# Out:
# 31262

# %%
train_data_1.head()
# Out:
#    id      賃料   築年数   面積m2  間取りID    所在    階層          経度         緯度  部屋数  \
# 0   1   75000   9.9  20.01      3   1.0  12.0  139.727873  35.747759  1.0
# 1   2   76000  45.0  16.50      9   5.0  10.0  139.780485  35.662406  1.0
# 2   3  110000   8.6  22.05      3  12.0  15.0  139.667375  35.675358  1.0
# 3   4  150000  29.4  60.48     14   3.0   4.0  139.648495  35.700193  3.5
# 4   5   74000  31.7  39.66     10   1.0   2.0  139.872315  35.766413  3.0
#
#    1部屋当たり面積m2       高さ率  建物構造ID        賃料/面積  平均坪単価（万円）  Unnamed: 4  flag
# 0       20.01  0.083333       3  3748.125937      180.0         NaN   NaN
# 1       16.50  0.500000      10  4606.060606      323.0         NaN   1.0
# 2       22.05  0.800000       3  4988.662132      324.0         NaN   NaN
# 3       17.28  0.750000       3  2480.158730      253.0         NaN   NaN
# 4       13.22  0.500000       7  1865.859808      111.0         NaN   NaN

# %%
test_data_1.head()
# Out:
#       id   築年数   面積m2  間取りID   所在   階層          経度         緯度  部屋数  \
# 0  31471  49.0  50.22     14  8.0  8.0  139.652762  35.617708  3.5
# 1  31472   0.2  20.88      9  3.0  4.0  139.672871  35.617709  1.0
# 2  31473  23.4  26.93      3  1.0  4.0  139.709049  35.741996  1.0
# 3  31474  36.2  23.57      3  1.0  2.0  139.658270  35.673602  1.0
# 5  31476  25.6  21.45      9  1.0  2.0  139.686023  35.691395  1.0
#
#    1部屋当たり面積m2   高さ率  建物構造ID  平均坪単価（万円）  Unnamed: 4  flag
# 0   14.348571  1.00      10      208.0         NaN   NaN
# 1   20.880000  0.75       3      273.0         NaN   NaN
# 2   26.930000  0.25      10      186.0         NaN   NaN
# 3   23.570000  0.50       7      184.0         NaN   NaN
# 5   21.450000  0.50       7      294.0         NaN   NaN

# %% [markdown]
# ## 4.学習

# %%
# IDとflagの削除
train_data_1_no_ID = train_data_1.drop(["id", "flag"], axis=1)
test_data_1_no_ID = test_data_1.drop(["id", "flag"], axis=1)

# %%
# 特徴データと目的変数の設定
train_x = train_data_1_no_ID.drop(["賃料", "賃料/面積"], axis=1)
train_y = train_data_1_no_ID["賃料/面積"]

test_x = test_data_1_no_ID

# %% [markdown]
# ## 5. 検証

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import log_loss, accuracy_score
from sklearn.model_selection import KFold

scores = []
# GBDT用のハイパーパラメータ
# params = {"objective": "reg:squarederror", "sileng":1, "random_state":71, "eval_metric":"rmse"}
# num_round = 50
params = {
    "silent": 1,
    "max_depth": 8, #best_param = 8
    "min_child_weight": 1,
    "eta": 0.1, #best_param = 0.1
    "tree_method": "exact",
    "objective": "reg:squarederror",
    "eval_metric": "rmse",
    "predictor": "cpu_predictor"
    "random_state":71
}
num_round = 50

# クロスバリデーション
kf = KFold(n_splits=4, shuffle=True, random_state=71)
for tr_idx, va_idx, in kf.split(train_x):
    tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
    tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]
    
    # GBDTで学習実行
    dtrain = xgb.DMatrix(tr_x, label=tr_y) # enable_categorical=True
    dvalid = xgb.DMatrix(va_x, label=va_y)
    dtest = xgb.DMatrix(test_x)
    
    watchlist = [(dtrain, "train"), (dvalid, "eval")]
#     model = xgb.train(params, dtrain, num_round, evals=watchlist)
    model = xgb.train(params=params,
                  dtrain=dtrain,
                  num_boost_round=1000,
                  early_stopping_rounds=10,
                  evals=watchlist)
# Out:
# [13:31:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:31:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-rmse:3351.79468	eval-rmse:3331.23340
# [1]	train-rmse:3028.17212	eval-rmse:3006.83130
# [2]	train-rmse:2737.37378	eval-rmse:2714.81372
# [3]	train-rmse:2476.19507	eval-rmse:2453.00415
# [4]	train-rmse:2241.70630	eval-rmse:2217.23853
# [5]	train-rmse:2031.19604	eval-rmse:2005.65710
# [6]	train-rmse:1842.25562	eval-rmse:1815.94934
# [7]	train-rmse:1672.93665	eval-rmse:1645.86047
# [8]	train-rmse:1521.37146	eval-rmse:1493.11475
# [9]	train-rmse:1385.61414	eval-rmse:1356.64404
# [10]	train-rmse:1264.44482	eval-rmse:1235.02808
# [11]	train-rmse:1156.19238	eval-rmse:1126.06140
# [12]	train-rmse:1060.09778	eval-rmse:1029.40833
# [13]	train-rmse:974.29596	eval-rmse:943.15241
# [14]	train-rmse:898.86664	eval-rmse:866.40363
# [15]	train-rmse:831.36707	eval-rmse:798.68988
# [16]	train-rmse:771.94165	eval-rmse:739.00738
# [17]	train-rmse:719.65582	eval-rmse:686.64453
# [18]	train-rmse:673.05859	eval-rmse:640.04089
# [19]	train-rmse:632.77508	eval-rmse:599.73926
# [20]	train-rmse:597.77734	eval-rmse:564.64508
# [21]	train-rmse:567.15137	eval-rmse:534.31885
# [22]	train-rmse:540.96600	eval-rmse:508.16183
# [23]	train-rmse:518.43024	eval-rmse:485.19730
# [24]	train-rmse:498.53308	eval-rmse:465.61737
# [25]	train-rmse:481.61032	eval-rmse:449.20773
# [26]	train-rmse:466.93311	eval-rmse:434.95425
# [27]	train-rmse:454.31433	eval-rmse:422.75891
# [28]	train-rmse:443.41296	eval-rmse:412.58319
# [29]	train-rmse:434.16779	eval-rmse:403.28403
# [30]	train-rmse:426.31241	eval-rmse:395.70608
# [31]	train-rmse:419.48276	eval-rmse:389.63620
# [32]	train-rmse:413.82422	eval-rmse:384.57400
# [33]	train-rmse:409.09793	eval-rmse:380.43576
# [34]	train-rmse:404.58389	eval-rmse:376.52515
# [35]	train-rmse:400.70828	eval-rmse:373.29367
# [36]	train-rmse:397.42786	eval-rmse:370.49835
# [37]	train-rmse:394.55078	eval-rmse:367.95608
# [38]	train-rmse:391.79053	eval-rmse:365.55203
# [39]	train-rmse:389.49237	eval-rmse:363.38934
# [40]	train-rmse:387.50574	eval-rmse:361.75586
# [41]	train-rmse:385.58850	eval-rmse:360.40713
# [42]	train-rmse:383.66907	eval-rmse:358.82904
# [43]	train-rmse:382.30447	eval-rmse:357.74969
# [44]	train-rmse:380.96704	eval-rmse:356.83481
# [45]	train-rmse:379.26227	eval-rmse:355.12860
# [46]	train-rmse:378.15585	eval-rmse:354.18768
# [47]	train-rmse:377.15533	eval-rmse:353.38654
# [48]	train-rmse:376.11813	eval-rmse:352.52170
# [49]	train-rmse:375.38684	eval-rmse:352.12494
# [50]	train-rmse:374.56552	eval-rmse:351.58179
# [51]	train-rmse:373.70474	eval-rmse:351.01950
# [52]	train-rmse:373.05313	eval-rmse:350.39114
# [53]	train-rmse:372.00922	eval-rmse:349.62830
# [54]	train-rmse:371.15027	eval-rmse:349.25433
# [55]	train-rmse:370.49359	eval-rmse:348.95276
# [56]	train-rmse:369.59512	eval-rmse:348.19772
# [57]	train-rmse:368.90509	eval-rmse:347.78918
# [58]	train-rmse:368.27920	eval-rmse:347.31399
# [59]	train-rmse:367.65347	eval-rmse:346.83734
# [60]	train-rmse:366.74933	eval-rmse:346.18890
# [61]	train-rmse:366.12808	eval-rmse:345.74777
# [62]	train-rmse:365.70441	eval-rmse:345.47156
# [63]	train-rmse:364.67068	eval-rmse:344.55750
# [64]	train-rmse:363.88281	eval-rmse:344.08316
# [65]	train-rmse:363.02457	eval-rmse:343.20602
# [66]	train-rmse:362.61490	eval-rmse:342.97186
# [67]	train-rmse:362.27414	eval-rmse:342.61566
# [68]	train-rmse:361.53357	eval-rmse:342.13675
# [69]	train-rmse:360.71576	eval-rmse:341.67343
# [70]	train-rmse:360.21829	eval-rmse:341.38068
# [71]	train-rmse:358.85599	eval-rmse:340.46155
# [72]	train-rmse:358.43881	eval-rmse:340.13800
# [73]	train-rmse:357.89450	eval-rmse:339.83313
# [74]	train-rmse:357.26566	eval-rmse:339.43481
# [75]	train-rmse:356.32596	eval-rmse:338.89652
# [76]	train-rmse:355.62405	eval-rmse:338.39282
# [77]	train-rmse:354.22043	eval-rmse:337.26697
# [78]	train-rmse:353.74268	eval-rmse:337.11285
# [79]	train-rmse:353.50259	eval-rmse:337.01224
# [80]	train-rmse:352.77222	eval-rmse:336.48816
# [81]	train-rmse:351.91742	eval-rmse:335.58130
# [82]	train-rmse:350.93942	eval-rmse:334.65103
# [83]	train-rmse:350.71195	eval-rmse:334.58981
# [84]	train-rmse:350.36169	eval-rmse:334.36050
# [85]	train-rmse:349.64795	eval-rmse:333.79282
# [86]	train-rmse:348.81488	eval-rmse:333.27060
# [87]	train-rmse:348.61679	eval-rmse:333.13074
# [88]	train-rmse:348.34271	eval-rmse:332.95447
# [89]	train-rmse:347.97324	eval-rmse:332.91129
# [90]	train-rmse:347.12427	eval-rmse:332.64435
# [91]	train-rmse:345.98096	eval-rmse:331.86417
# [92]	train-rmse:345.40088	eval-rmse:331.49768
# [93]	train-rmse:344.97733	eval-rmse:331.19076
# [94]	train-rmse:344.86478	eval-rmse:331.09341
# [95]	train-rmse:344.20557	eval-rmse:330.67963
# [96]	train-rmse:343.64594	eval-rmse:330.31616
# [97]	train-rmse:343.03900	eval-rmse:330.14166
# [98]	train-rmse:342.56625	eval-rmse:329.94867
# [99]	train-rmse:342.17819	eval-rmse:329.65891
# [100]	train-rmse:341.92676	eval-rmse:329.44022
# [101]	train-rmse:341.62384	eval-rmse:329.36548
# [102]	train-rmse:341.17361	eval-rmse:329.17246
# [103]	train-rmse:340.69559	eval-rmse:328.98438
# [104]	train-rmse:340.46524	eval-rmse:328.89130
# [105]	train-rmse:340.16324	eval-rmse:328.81805
# [106]	train-rmse:339.98526	eval-rmse:328.72842
# [107]	train-rmse:339.70725	eval-rmse:328.61588
# [108]	train-rmse:339.60062	eval-rmse:328.51727
# [109]	train-rmse:339.32541	eval-rmse:328.48450
# [110]	train-rmse:338.85251	eval-rmse:328.00168
# [111]	train-rmse:338.42227	eval-rmse:327.62854
# [112]	train-rmse:338.06842	eval-rmse:327.41333
# [113]	train-rmse:337.91754	eval-rmse:327.36926
# [114]	train-rmse:337.70480	eval-rmse:327.34778
# [115]	train-rmse:337.45071	eval-rmse:327.27506
# [116]	train-rmse:337.11139	eval-rmse:327.20297
# [117]	train-rmse:336.42859	eval-rmse:326.62616
# [118]	train-rmse:335.96780	eval-rmse:326.39163
# [119]	train-rmse:335.63495	eval-rmse:326.11713
# [120]	train-rmse:335.28287	eval-rmse:325.86383
# [121]	train-rmse:334.88800	eval-rmse:325.60138
# [122]	train-rmse:334.62466	eval-rmse:325.46478
# [123]	train-rmse:334.30917	eval-rmse:325.31424
# [124]	train-rmse:333.97421	eval-rmse:325.16742
# [125]	train-rmse:333.50232	eval-rmse:324.66058
# [126]	train-rmse:333.25424	eval-rmse:324.55924
# [127]	train-rmse:333.11511	eval-rmse:324.50418
# [128]	train-rmse:332.85049	eval-rmse:324.38650
# [129]	train-rmse:332.61908	eval-rmse:324.32178
# [130]	train-rmse:332.42831	eval-rmse:324.14655
# [131]	train-rmse:331.91946	eval-rmse:323.94287
# [132]	train-rmse:331.51111	eval-rmse:323.65610
# [133]	train-rmse:330.82181	eval-rmse:323.27972
# [134]	train-rmse:330.44193	eval-rmse:323.00909
# [135]	train-rmse:330.17877	eval-rmse:322.86243
# [136]	train-rmse:330.02188	eval-rmse:322.72690
# [137]	train-rmse:329.62134	eval-rmse:322.56003
# [138]	train-rmse:329.40405	eval-rmse:322.46371
# [139]	train-rmse:328.89203	eval-rmse:322.11774
# [140]	train-rmse:328.35977	eval-rmse:321.79550
# [141]	train-rmse:328.22855	eval-rmse:321.74310
# [142]	train-rmse:327.95084	eval-rmse:321.66208
# [143]	train-rmse:327.35287	eval-rmse:321.35123
# [144]	train-rmse:327.22757	eval-rmse:321.38300
# [145]	train-rmse:326.98294	eval-rmse:321.30322
# [146]	train-rmse:326.55063	eval-rmse:320.90311
# [147]	train-rmse:326.10944	eval-rmse:320.68146
# [148]	train-rmse:325.75430	eval-rmse:320.49582
# [149]	train-rmse:325.56476	eval-rmse:320.42004
# [150]	train-rmse:325.41531	eval-rmse:320.35523
# [151]	train-rmse:325.06631	eval-rmse:320.25510
# [152]	train-rmse:324.88919	eval-rmse:320.14633
# [153]	train-rmse:324.87894	eval-rmse:320.14841
# [154]	train-rmse:324.65659	eval-rmse:319.98886
# [155]	train-rmse:324.51111	eval-rmse:319.89600
# [156]	train-rmse:324.40991	eval-rmse:319.89462
# [157]	train-rmse:324.22241	eval-rmse:319.80621
# [158]	train-rmse:323.94458	eval-rmse:319.62329
# [159]	train-rmse:323.56802	eval-rmse:319.47324
# [160]	train-rmse:323.34814	eval-rmse:319.34604
# [161]	train-rmse:323.21826	eval-rmse:319.27389
# [162]	train-rmse:323.10596	eval-rmse:319.26245
# [163]	train-rmse:322.91711	eval-rmse:319.14951
# [164]	train-rmse:322.56338	eval-rmse:318.99069
# [165]	train-rmse:322.45496	eval-rmse:318.96432
# [166]	train-rmse:322.14789	eval-rmse:318.68219
# [167]	train-rmse:322.01990	eval-rmse:318.67505
# [168]	train-rmse:321.88702	eval-rmse:318.64868
# [169]	train-rmse:321.69861	eval-rmse:318.58093
# [170]	train-rmse:321.16656	eval-rmse:318.49646
# [171]	train-rmse:321.11539	eval-rmse:318.46719
# [172]	train-rmse:320.78302	eval-rmse:318.17801
# [173]	train-rmse:320.61960	eval-rmse:318.10016
# [174]	train-rmse:320.49728	eval-rmse:318.03171
# [175]	train-rmse:320.09976	eval-rmse:317.79623
# [176]	train-rmse:319.84528	eval-rmse:317.75464
# [177]	train-rmse:319.65936	eval-rmse:317.65289
# [178]	train-rmse:319.42068	eval-rmse:317.59451
# [179]	train-rmse:319.06833	eval-rmse:317.40362
# [180]	train-rmse:318.67682	eval-rmse:317.18982
# [181]	train-rmse:318.23047	eval-rmse:316.96439
# [182]	train-rmse:318.01666	eval-rmse:316.87357
# [183]	train-rmse:317.38162	eval-rmse:316.69751
# [184]	train-rmse:317.18683	eval-rmse:316.71411
# [185]	train-rmse:317.06595	eval-rmse:316.67764
# [186]	train-rmse:316.89667	eval-rmse:316.49890
# [187]	train-rmse:316.32916	eval-rmse:316.14004
# [188]	train-rmse:316.00281	eval-rmse:316.01157
# [189]	train-rmse:315.79184	eval-rmse:315.92651
# [190]	train-rmse:315.35733	eval-rmse:315.67541
# [191]	train-rmse:315.06424	eval-rmse:315.51031
# [192]	train-rmse:314.85165	eval-rmse:315.40152
# [193]	train-rmse:314.80756	eval-rmse:315.40698
# [194]	train-rmse:314.76294	eval-rmse:315.35919
# [195]	train-rmse:314.53931	eval-rmse:315.26834
# [196]	train-rmse:314.26965	eval-rmse:315.17221
# [197]	train-rmse:314.13266	eval-rmse:315.12643
# [198]	train-rmse:314.00116	eval-rmse:315.05737
# [199]	train-rmse:313.63687	eval-rmse:314.83957
# [200]	train-rmse:313.45319	eval-rmse:314.73059
# [201]	train-rmse:313.34174	eval-rmse:314.73691
# [202]	train-rmse:313.23871	eval-rmse:314.71237
# [203]	train-rmse:313.18103	eval-rmse:314.67331
# [204]	train-rmse:312.61520	eval-rmse:314.39810
# [205]	train-rmse:312.45749	eval-rmse:314.29941
# [206]	train-rmse:312.26834	eval-rmse:314.28909
# [207]	train-rmse:311.94611	eval-rmse:314.13355
# [208]	train-rmse:311.89572	eval-rmse:314.11395
# [209]	train-rmse:311.77191	eval-rmse:314.06595
# [210]	train-rmse:311.22470	eval-rmse:313.79639
# [211]	train-rmse:311.12237	eval-rmse:313.75461
# [212]	train-rmse:310.96686	eval-rmse:313.68424
# [213]	train-rmse:310.67328	eval-rmse:313.67313
# [214]	train-rmse:310.60196	eval-rmse:313.61990
# [215]	train-rmse:310.55280	eval-rmse:313.60306
# [216]	train-rmse:310.39935	eval-rmse:313.52899
# [217]	train-rmse:310.01584	eval-rmse:313.52063
# [218]	train-rmse:309.88492	eval-rmse:313.52698
# [219]	train-rmse:309.84564	eval-rmse:313.52664
# [220]	train-rmse:309.77521	eval-rmse:313.51022
# [221]	train-rmse:309.53262	eval-rmse:313.38702
# [222]	train-rmse:309.50058	eval-rmse:313.36798
# [223]	train-rmse:309.28253	eval-rmse:313.35516
# [224]	train-rmse:309.08130	eval-rmse:313.31195
# [225]	train-rmse:308.83844	eval-rmse:313.21030
# [226]	train-rmse:308.52756	eval-rmse:313.10104
# [227]	train-rmse:308.51675	eval-rmse:313.09595
# [228]	train-rmse:308.26318	eval-rmse:313.00952
# [229]	train-rmse:308.08316	eval-rmse:312.88596
# [230]	train-rmse:307.90314	eval-rmse:312.80078
# [231]	train-rmse:307.82907	eval-rmse:312.79654
# [232]	train-rmse:307.72345	eval-rmse:312.78348
# [233]	train-rmse:307.40308	eval-rmse:312.66943
# [234]	train-rmse:306.80765	eval-rmse:312.38541
# [235]	train-rmse:306.51379	eval-rmse:312.17337
# [236]	train-rmse:306.43512	eval-rmse:312.19113
# [237]	train-rmse:306.38251	eval-rmse:312.16919
# [238]	train-rmse:306.29504	eval-rmse:312.09024
# [239]	train-rmse:306.09280	eval-rmse:312.01581
# [240]	train-rmse:305.96793	eval-rmse:311.95404
# [241]	train-rmse:305.76028	eval-rmse:311.78531
# [242]	train-rmse:305.70529	eval-rmse:311.75836
# [243]	train-rmse:305.58688	eval-rmse:311.73318
# [244]	train-rmse:305.54098	eval-rmse:311.72742
# [245]	train-rmse:305.35364	eval-rmse:311.59180
# [246]	train-rmse:305.13861	eval-rmse:311.57199
# [247]	train-rmse:305.09885	eval-rmse:311.54095
# [248]	train-rmse:305.04678	eval-rmse:311.50305
# [249]	train-rmse:304.56882	eval-rmse:311.35348
# [250]	train-rmse:304.40936	eval-rmse:311.25644
# [251]	train-rmse:304.35159	eval-rmse:311.19855
# [252]	train-rmse:304.09369	eval-rmse:311.03439
# [253]	train-rmse:303.90274	eval-rmse:310.95914
# [254]	train-rmse:303.65164	eval-rmse:310.83511
# [255]	train-rmse:303.49835	eval-rmse:310.76056
# [256]	train-rmse:303.30380	eval-rmse:310.73248
# [257]	train-rmse:303.20450	eval-rmse:310.74637
# [258]	train-rmse:303.11820	eval-rmse:310.72745
# [259]	train-rmse:303.03012	eval-rmse:310.67654
# [260]	train-rmse:302.67377	eval-rmse:310.58188
# [261]	train-rmse:302.38260	eval-rmse:310.35431
# [262]	train-rmse:302.22388	eval-rmse:310.26740
# [263]	train-rmse:302.07623	eval-rmse:310.19284
# [264]	train-rmse:301.95874	eval-rmse:310.17471
# [265]	train-rmse:301.66861	eval-rmse:310.08304
# [266]	train-rmse:301.32538	eval-rmse:310.02325
# [267]	train-rmse:300.99948	eval-rmse:310.01843
# [268]	train-rmse:300.87851	eval-rmse:309.95102
# [269]	train-rmse:300.65686	eval-rmse:309.90726
# [270]	train-rmse:300.40537	eval-rmse:309.85409
# [271]	train-rmse:300.17862	eval-rmse:309.85687
# [272]	train-rmse:300.03784	eval-rmse:309.88272
# [273]	train-rmse:299.95355	eval-rmse:309.84106
# [274]	train-rmse:299.89343	eval-rmse:309.82111
# [275]	train-rmse:299.62176	eval-rmse:309.70911
# [276]	train-rmse:299.51303	eval-rmse:309.65414
# [277]	train-rmse:299.29202	eval-rmse:309.50540
# [278]	train-rmse:299.21838	eval-rmse:309.47250
# [279]	train-rmse:299.02487	eval-rmse:309.39569
# [280]	train-rmse:298.97540	eval-rmse:309.40125
# [281]	train-rmse:298.90848	eval-rmse:309.41010
# [282]	train-rmse:298.83719	eval-rmse:309.37897
# [283]	train-rmse:298.73297	eval-rmse:309.32538
# [284]	train-rmse:298.56445	eval-rmse:309.18613
# [285]	train-rmse:298.36612	eval-rmse:309.07745
# [286]	train-rmse:298.22397	eval-rmse:309.00494
# [287]	train-rmse:298.14529	eval-rmse:308.96527
# [288]	train-rmse:298.04031	eval-rmse:308.94522
# [289]	train-rmse:297.92493	eval-rmse:308.87256
# [290]	train-rmse:297.81207	eval-rmse:308.81378
# [291]	train-rmse:297.64591	eval-rmse:308.77365
# [292]	train-rmse:297.40561	eval-rmse:308.76062
# [293]	train-rmse:297.23291	eval-rmse:308.71817
# [294]	train-rmse:297.13211	eval-rmse:308.66974
# [295]	train-rmse:297.07800	eval-rmse:308.66528
# [296]	train-rmse:297.04694	eval-rmse:308.70267
# [297]	train-rmse:296.67246	eval-rmse:308.51086
# [298]	train-rmse:296.49109	eval-rmse:308.44019
# [299]	train-rmse:296.41101	eval-rmse:308.38178
# [300]	train-rmse:296.36014	eval-rmse:308.36099
# [301]	train-rmse:296.31787	eval-rmse:308.31845
# [302]	train-rmse:296.25031	eval-rmse:308.31601
# [303]	train-rmse:296.14786	eval-rmse:308.25424
# [304]	train-rmse:295.84970	eval-rmse:308.12656
# [305]	train-rmse:295.75781	eval-rmse:308.10113
# [306]	train-rmse:295.66647	eval-rmse:308.05399
# [307]	train-rmse:295.51389	eval-rmse:308.01587
# [308]	train-rmse:295.50555	eval-rmse:308.01285
# [309]	train-rmse:295.32230	eval-rmse:307.91803
# [310]	train-rmse:295.13831	eval-rmse:307.80676
# [311]	train-rmse:294.94138	eval-rmse:307.71527
# [312]	train-rmse:294.80164	eval-rmse:307.68951
# [313]	train-rmse:294.58014	eval-rmse:307.56293
# [314]	train-rmse:294.35348	eval-rmse:307.43466
# [315]	train-rmse:294.01743	eval-rmse:307.30158
# [316]	train-rmse:293.93329	eval-rmse:307.25855
# [317]	train-rmse:293.60236	eval-rmse:307.13531
# [318]	train-rmse:293.46432	eval-rmse:307.05170
# [319]	train-rmse:293.38126	eval-rmse:307.00284
# [320]	train-rmse:293.32425	eval-rmse:306.96924
# [321]	train-rmse:293.18094	eval-rmse:306.91565
# [322]	train-rmse:293.09128	eval-rmse:306.86758
# [323]	train-rmse:292.99448	eval-rmse:306.84683
# [324]	train-rmse:292.90173	eval-rmse:306.83087
# [325]	train-rmse:292.79126	eval-rmse:306.78241
# [326]	train-rmse:292.63742	eval-rmse:306.74027
# [327]	train-rmse:292.45334	eval-rmse:306.64401
# [328]	train-rmse:292.27832	eval-rmse:306.58981
# [329]	train-rmse:291.99851	eval-rmse:306.55173
# [330]	train-rmse:291.73666	eval-rmse:306.42947
# [331]	train-rmse:291.56049	eval-rmse:306.32465
# [332]	train-rmse:291.46207	eval-rmse:306.28055
# [333]	train-rmse:291.39853	eval-rmse:306.25711
# [334]	train-rmse:291.11420	eval-rmse:306.10605
# [335]	train-rmse:291.04028	eval-rmse:306.03937
# [336]	train-rmse:290.96017	eval-rmse:306.00027
# [337]	train-rmse:290.76529	eval-rmse:305.90234
# [338]	train-rmse:290.69766	eval-rmse:305.89066
# [339]	train-rmse:290.67117	eval-rmse:305.88678
# [340]	train-rmse:290.63165	eval-rmse:305.86786
# [341]	train-rmse:290.52014	eval-rmse:305.84851
# [342]	train-rmse:290.41055	eval-rmse:305.77524
# [343]	train-rmse:290.32263	eval-rmse:305.74750
# [344]	train-rmse:290.10388	eval-rmse:305.66827
# [345]	train-rmse:289.95804	eval-rmse:305.61319
# [346]	train-rmse:289.68674	eval-rmse:305.45999
# [347]	train-rmse:289.35965	eval-rmse:305.38287
# [348]	train-rmse:289.28220	eval-rmse:305.34903
# [349]	train-rmse:289.27261	eval-rmse:305.34738
# [350]	train-rmse:289.01221	eval-rmse:305.18552
# [351]	train-rmse:288.74164	eval-rmse:305.10861
# [352]	train-rmse:288.60355	eval-rmse:305.00894
# [353]	train-rmse:288.54718	eval-rmse:304.96805
# [354]	train-rmse:288.36722	eval-rmse:304.86154
# [355]	train-rmse:288.27838	eval-rmse:304.80258
# [356]	train-rmse:288.13763	eval-rmse:304.80045
# [357]	train-rmse:288.06415	eval-rmse:304.77197
# [358]	train-rmse:287.95743	eval-rmse:304.72031
# [359]	train-rmse:287.87674	eval-rmse:304.66571
# [360]	train-rmse:287.72559	eval-rmse:304.62274
# [361]	train-rmse:287.69650	eval-rmse:304.60739
# [362]	train-rmse:287.63379	eval-rmse:304.56873
# [363]	train-rmse:287.57513	eval-rmse:304.55539
# [364]	train-rmse:287.50345	eval-rmse:304.54498
# [365]	train-rmse:287.43320	eval-rmse:304.52908
# [366]	train-rmse:287.33316	eval-rmse:304.49200
# [367]	train-rmse:287.19342	eval-rmse:304.42541
# [368]	train-rmse:287.01663	eval-rmse:304.30890
# [369]	train-rmse:286.78690	eval-rmse:304.30087
# [370]	train-rmse:286.59644	eval-rmse:304.20254
# [371]	train-rmse:286.48721	eval-rmse:304.12915
# [372]	train-rmse:286.36026	eval-rmse:304.09494
# [373]	train-rmse:286.23966	eval-rmse:304.08514
# [374]	train-rmse:286.14450	eval-rmse:304.08227
# [375]	train-rmse:285.94229	eval-rmse:304.07626
# [376]	train-rmse:285.91480	eval-rmse:304.06738
# [377]	train-rmse:285.87271	eval-rmse:304.03931
# [378]	train-rmse:285.79446	eval-rmse:303.99252
# [379]	train-rmse:285.63306	eval-rmse:303.93933
# [380]	train-rmse:285.50168	eval-rmse:303.88544
# [381]	train-rmse:285.47104	eval-rmse:303.87836
# [382]	train-rmse:285.34357	eval-rmse:303.83115
# [383]	train-rmse:285.24765	eval-rmse:303.76581
# [384]	train-rmse:285.17471	eval-rmse:303.71298
# [385]	train-rmse:284.92566	eval-rmse:303.53964
# [386]	train-rmse:284.82495	eval-rmse:303.55786
# [387]	train-rmse:284.72089	eval-rmse:303.52368
# [388]	train-rmse:284.64304	eval-rmse:303.49304
# [389]	train-rmse:284.63184	eval-rmse:303.49036
# [390]	train-rmse:284.56506	eval-rmse:303.46347
# [391]	train-rmse:284.47318	eval-rmse:303.41678
# [392]	train-rmse:284.37347	eval-rmse:303.36105
# [393]	train-rmse:284.23441	eval-rmse:303.36533
# [394]	train-rmse:284.10931	eval-rmse:303.32788
# [395]	train-rmse:284.04059	eval-rmse:303.30359
# [396]	train-rmse:283.95129	eval-rmse:303.22885
# [397]	train-rmse:283.85370	eval-rmse:303.22702
# [398]	train-rmse:283.69293	eval-rmse:303.20212
# [399]	train-rmse:283.61850	eval-rmse:303.14493
# [400]	train-rmse:283.59689	eval-rmse:303.12784
# [401]	train-rmse:283.48773	eval-rmse:303.14407
# [402]	train-rmse:283.36017	eval-rmse:303.04627
# [403]	train-rmse:283.24252	eval-rmse:303.03983
# [404]	train-rmse:283.20749	eval-rmse:303.03821
# [405]	train-rmse:283.13910	eval-rmse:303.02908
# [406]	train-rmse:283.02124	eval-rmse:303.00531
# [407]	train-rmse:282.93021	eval-rmse:303.03174
# [408]	train-rmse:282.89410	eval-rmse:303.02091
# [409]	train-rmse:282.81009	eval-rmse:302.97195
# [410]	train-rmse:282.71378	eval-rmse:302.90756
# [411]	train-rmse:282.61191	eval-rmse:302.90659
# [412]	train-rmse:282.59518	eval-rmse:302.89740
# [413]	train-rmse:282.34106	eval-rmse:302.88019
# [414]	train-rmse:282.18982	eval-rmse:302.77145
# [415]	train-rmse:282.03168	eval-rmse:302.77631
# [416]	train-rmse:281.85452	eval-rmse:302.69409
# [417]	train-rmse:281.63022	eval-rmse:302.65329
# [418]	train-rmse:281.53970	eval-rmse:302.61615
# [419]	train-rmse:281.49326	eval-rmse:302.60019
# [420]	train-rmse:281.40717	eval-rmse:302.58444
# [421]	train-rmse:281.32898	eval-rmse:302.54742
# [422]	train-rmse:281.20126	eval-rmse:302.48230
# [423]	train-rmse:281.10165	eval-rmse:302.39969
# [424]	train-rmse:281.06818	eval-rmse:302.39764
# [425]	train-rmse:280.94699	eval-rmse:302.34570
# [426]	train-rmse:280.91022	eval-rmse:302.34180
# [427]	train-rmse:280.82690	eval-rmse:302.27026
# [428]	train-rmse:280.80158	eval-rmse:302.27588
# [429]	train-rmse:280.73642	eval-rmse:302.25241
# [430]	train-rmse:280.67422	eval-rmse:302.26038
# [431]	train-rmse:280.45917	eval-rmse:302.22461
# [432]	train-rmse:280.38910	eval-rmse:302.19714
# [433]	train-rmse:280.26630	eval-rmse:302.16836
# [434]	train-rmse:280.05267	eval-rmse:302.09372
# [435]	train-rmse:279.92645	eval-rmse:301.99356
# [436]	train-rmse:279.84808	eval-rmse:301.95200
# [437]	train-rmse:279.78571	eval-rmse:301.94025
# [438]	train-rmse:279.72696	eval-rmse:301.88297
# [439]	train-rmse:279.66812	eval-rmse:301.87649
# [440]	train-rmse:279.60364	eval-rmse:301.83627
# [441]	train-rmse:279.45685	eval-rmse:301.83871
# [442]	train-rmse:279.26907	eval-rmse:301.78714
# [443]	train-rmse:279.07556	eval-rmse:301.72205
# [444]	train-rmse:278.96277	eval-rmse:301.69430
# [445]	train-rmse:278.75674	eval-rmse:301.65439
# [446]	train-rmse:278.71307	eval-rmse:301.62592
# [447]	train-rmse:278.57596	eval-rmse:301.56247
# [448]	train-rmse:278.48496	eval-rmse:301.52676
# [449]	train-rmse:278.39182	eval-rmse:301.46185
# [450]	train-rmse:278.32828	eval-rmse:301.48602
# [451]	train-rmse:278.23694	eval-rmse:301.46191
# [452]	train-rmse:278.05228	eval-rmse:301.31576
# [453]	train-rmse:277.96713	eval-rmse:301.26944
# [454]	train-rmse:277.84701	eval-rmse:301.25561
# [455]	train-rmse:277.71442	eval-rmse:301.22037
# [456]	train-rmse:277.64301	eval-rmse:301.18027
# [457]	train-rmse:277.57712	eval-rmse:301.13528
# [458]	train-rmse:277.46048	eval-rmse:301.07465
# [459]	train-rmse:277.38672	eval-rmse:301.07867
# [460]	train-rmse:277.27887	eval-rmse:301.07330
# [461]	train-rmse:277.12604	eval-rmse:301.00131
# [462]	train-rmse:277.02402	eval-rmse:300.95666
# [463]	train-rmse:276.94925	eval-rmse:300.92950
# [464]	train-rmse:276.88507	eval-rmse:300.89655
# [465]	train-rmse:276.85019	eval-rmse:300.87970
# [466]	train-rmse:276.74747	eval-rmse:300.85144
# [467]	train-rmse:276.71100	eval-rmse:300.83432
# [468]	train-rmse:276.54980	eval-rmse:300.83389
# [469]	train-rmse:276.48492	eval-rmse:300.84018
# [470]	train-rmse:276.41406	eval-rmse:300.83044
# [471]	train-rmse:276.39404	eval-rmse:300.82574
# [472]	train-rmse:276.37961	eval-rmse:300.82556
# [473]	train-rmse:276.27109	eval-rmse:300.77408
# [474]	train-rmse:276.20837	eval-rmse:300.71887
# [475]	train-rmse:276.12494	eval-rmse:300.69348
# [476]	train-rmse:276.06396	eval-rmse:300.67526
# [477]	train-rmse:275.98611	eval-rmse:300.65863
# [478]	train-rmse:275.91403	eval-rmse:300.64929
# [479]	train-rmse:275.83853	eval-rmse:300.61499
# [480]	train-rmse:275.81625	eval-rmse:300.61398
# [481]	train-rmse:275.70187	eval-rmse:300.60989
# [482]	train-rmse:275.56421	eval-rmse:300.57227
# [483]	train-rmse:275.48389	eval-rmse:300.55264
# [484]	train-rmse:275.43381	eval-rmse:300.54627
# [485]	train-rmse:275.40149	eval-rmse:300.53912
# [486]	train-rmse:275.28122	eval-rmse:300.53967
# [487]	train-rmse:275.11197	eval-rmse:300.49561
# [488]	train-rmse:275.01150	eval-rmse:300.44571
# [489]	train-rmse:274.91455	eval-rmse:300.39011
# [490]	train-rmse:274.89505	eval-rmse:300.39066
# [491]	train-rmse:274.80789	eval-rmse:300.37909
# [492]	train-rmse:274.72647	eval-rmse:300.34012
# [493]	train-rmse:274.65540	eval-rmse:300.32538
# [494]	train-rmse:274.53500	eval-rmse:300.30231
# [495]	train-rmse:274.43329	eval-rmse:300.29437
# [496]	train-rmse:274.43008	eval-rmse:300.29529
# [497]	train-rmse:274.35382	eval-rmse:300.23688
# [498]	train-rmse:274.31198	eval-rmse:300.22827
# [499]	train-rmse:274.27679	eval-rmse:300.22809
# [500]	train-rmse:273.97852	eval-rmse:300.14175
# [501]	train-rmse:273.91516	eval-rmse:300.11224
# [502]	train-rmse:273.84967	eval-rmse:300.07150
# [503]	train-rmse:273.76315	eval-rmse:300.02106
# [504]	train-rmse:273.70682	eval-rmse:299.99637
# [505]	train-rmse:273.48129	eval-rmse:299.97861
# [506]	train-rmse:273.34271	eval-rmse:299.92285
# [507]	train-rmse:273.25613	eval-rmse:299.87946
# [508]	train-rmse:273.15143	eval-rmse:299.80689
# [509]	train-rmse:273.13770	eval-rmse:299.81271
# [510]	train-rmse:273.12494	eval-rmse:299.79910
# [511]	train-rmse:273.08835	eval-rmse:299.79797
# [512]	train-rmse:273.07233	eval-rmse:299.78528
# [513]	train-rmse:272.99942	eval-rmse:299.72989
# [514]	train-rmse:272.93484	eval-rmse:299.71045
# [515]	train-rmse:272.87338	eval-rmse:299.67328
# [516]	train-rmse:272.72943	eval-rmse:299.61194
# [517]	train-rmse:272.59653	eval-rmse:299.54559
# [518]	train-rmse:272.54990	eval-rmse:299.51962
# [519]	train-rmse:272.46173	eval-rmse:299.49600
# [520]	train-rmse:272.41037	eval-rmse:299.46982
# [521]	train-rmse:272.37323	eval-rmse:299.44611
# [522]	train-rmse:272.21680	eval-rmse:299.40515
# [523]	train-rmse:272.10904	eval-rmse:299.37616
# [524]	train-rmse:272.08191	eval-rmse:299.37909
# [525]	train-rmse:272.04416	eval-rmse:299.33426
# [526]	train-rmse:272.01880	eval-rmse:299.33670
# [527]	train-rmse:271.96808	eval-rmse:299.33545
# [528]	train-rmse:271.90613	eval-rmse:299.30566
# [529]	train-rmse:271.82520	eval-rmse:299.25775
# [530]	train-rmse:271.73468	eval-rmse:299.16849
# [531]	train-rmse:271.72128	eval-rmse:299.16373
# [532]	train-rmse:271.70868	eval-rmse:299.16492
# [533]	train-rmse:271.63248	eval-rmse:299.13467
# [534]	train-rmse:271.55817	eval-rmse:299.06808
# [535]	train-rmse:271.32398	eval-rmse:299.01337
# [536]	train-rmse:271.27206	eval-rmse:298.99075
# [537]	train-rmse:271.23428	eval-rmse:299.01355
# [538]	train-rmse:271.13919	eval-rmse:299.00912
# [539]	train-rmse:271.00263	eval-rmse:298.95084
# [540]	train-rmse:270.95682	eval-rmse:298.93527
# [541]	train-rmse:270.90076	eval-rmse:298.89621
# [542]	train-rmse:270.79672	eval-rmse:298.92502
# [543]	train-rmse:270.69513	eval-rmse:298.88956
# [544]	train-rmse:270.69003	eval-rmse:298.87570
# [545]	train-rmse:270.67355	eval-rmse:298.86410
# [546]	train-rmse:270.58997	eval-rmse:298.82678
# [547]	train-rmse:270.57047	eval-rmse:298.83463
# [548]	train-rmse:270.53024	eval-rmse:298.82947
# [549]	train-rmse:270.47418	eval-rmse:298.81497
# [550]	train-rmse:270.34369	eval-rmse:298.75397
# [551]	train-rmse:270.28980	eval-rmse:298.73318
# [552]	train-rmse:270.24652	eval-rmse:298.72952
# [553]	train-rmse:270.16171	eval-rmse:298.68088
# [554]	train-rmse:270.01126	eval-rmse:298.61600
# [555]	train-rmse:269.94867	eval-rmse:298.60672
# [556]	train-rmse:269.89337	eval-rmse:298.58987
# [557]	train-rmse:269.80743	eval-rmse:298.55566
# [558]	train-rmse:269.74298	eval-rmse:298.53983
# [559]	train-rmse:269.61502	eval-rmse:298.51312
# [560]	train-rmse:269.57895	eval-rmse:298.49548
# [561]	train-rmse:269.52539	eval-rmse:298.49905
# [562]	train-rmse:269.50381	eval-rmse:298.47180
# [563]	train-rmse:269.47580	eval-rmse:298.47223
# [564]	train-rmse:269.41574	eval-rmse:298.45209
# [565]	train-rmse:269.38083	eval-rmse:298.41946
# [566]	train-rmse:269.27853	eval-rmse:298.39502
# [567]	train-rmse:269.20493	eval-rmse:298.43204
# [568]	train-rmse:269.05261	eval-rmse:298.38391
# [569]	train-rmse:268.93326	eval-rmse:298.36264
# [570]	train-rmse:268.88217	eval-rmse:298.35501
# [571]	train-rmse:268.84378	eval-rmse:298.35443
# [572]	train-rmse:268.80426	eval-rmse:298.37164
# [573]	train-rmse:268.71161	eval-rmse:298.34607
# [574]	train-rmse:268.67773	eval-rmse:298.32776
# [575]	train-rmse:268.65219	eval-rmse:298.31641
# [576]	train-rmse:268.47681	eval-rmse:298.27866
# [577]	train-rmse:268.43433	eval-rmse:298.28439
# [578]	train-rmse:268.25885	eval-rmse:298.25769
# [579]	train-rmse:268.21020	eval-rmse:298.23285
# [580]	train-rmse:268.19849	eval-rmse:298.23187
# [581]	train-rmse:268.14139	eval-rmse:298.20456
# [582]	train-rmse:268.07419	eval-rmse:298.16617
# [583]	train-rmse:268.04504	eval-rmse:298.15768
# [584]	train-rmse:268.01526	eval-rmse:298.16977
# [585]	train-rmse:267.97958	eval-rmse:298.14597
# [586]	train-rmse:267.92847	eval-rmse:298.10294
# [587]	train-rmse:267.86423	eval-rmse:298.05942
# [588]	train-rmse:267.84854	eval-rmse:298.05008
# [589]	train-rmse:267.79953	eval-rmse:298.04575
# [590]	train-rmse:267.73163	eval-rmse:297.99994
# [591]	train-rmse:267.65308	eval-rmse:297.97775
# [592]	train-rmse:267.58005	eval-rmse:297.94449
# [593]	train-rmse:267.53195	eval-rmse:297.89554
# [594]	train-rmse:267.50787	eval-rmse:297.89508
# [595]	train-rmse:267.42014	eval-rmse:297.85007
# [596]	train-rmse:267.38541	eval-rmse:297.83945
# [597]	train-rmse:267.31561	eval-rmse:297.80615
# [598]	train-rmse:267.23804	eval-rmse:297.77267
# [599]	train-rmse:267.10751	eval-rmse:297.69943
# [600]	train-rmse:267.07574	eval-rmse:297.71963
# [601]	train-rmse:266.98761	eval-rmse:297.71085
# [602]	train-rmse:266.89929	eval-rmse:297.64645
# [603]	train-rmse:266.86795	eval-rmse:297.65918
# [604]	train-rmse:266.84647	eval-rmse:297.65234
# [605]	train-rmse:266.77463	eval-rmse:297.62793
# [606]	train-rmse:266.67416	eval-rmse:297.64893
# [607]	train-rmse:266.62784	eval-rmse:297.60449
# [608]	train-rmse:266.58707	eval-rmse:297.58963
# [609]	train-rmse:266.55377	eval-rmse:297.56537
# [610]	train-rmse:266.42545	eval-rmse:297.57932
# [611]	train-rmse:266.41388	eval-rmse:297.57019
# [612]	train-rmse:266.37424	eval-rmse:297.54306
# [613]	train-rmse:266.30005	eval-rmse:297.53052
# [614]	train-rmse:266.24435	eval-rmse:297.51782
# [615]	train-rmse:266.15396	eval-rmse:297.53409
# [616]	train-rmse:266.08099	eval-rmse:297.51645
# [617]	train-rmse:266.01657	eval-rmse:297.49353
# [618]	train-rmse:265.89600	eval-rmse:297.48209
# [619]	train-rmse:265.85736	eval-rmse:297.46545
# [620]	train-rmse:265.82754	eval-rmse:297.46271
# [621]	train-rmse:265.81909	eval-rmse:297.45425
# [622]	train-rmse:265.79581	eval-rmse:297.43378
# [623]	train-rmse:265.74258	eval-rmse:297.41119
# [624]	train-rmse:265.70963	eval-rmse:297.40115
# [625]	train-rmse:265.64566	eval-rmse:297.37305
# [626]	train-rmse:265.63950	eval-rmse:297.37649
# [627]	train-rmse:265.61569	eval-rmse:297.36432
# [628]	train-rmse:265.60523	eval-rmse:297.35461
# [629]	train-rmse:265.51205	eval-rmse:297.33313
# [630]	train-rmse:265.45444	eval-rmse:297.32858
# [631]	train-rmse:265.41998	eval-rmse:297.32663
# [632]	train-rmse:265.33032	eval-rmse:297.31805
# [633]	train-rmse:265.25638	eval-rmse:297.27631
# [634]	train-rmse:265.22754	eval-rmse:297.26126
# [635]	train-rmse:265.14673	eval-rmse:297.26239
# [636]	train-rmse:265.07013	eval-rmse:297.23373
# [637]	train-rmse:265.04724	eval-rmse:297.23688
# [638]	train-rmse:264.98526	eval-rmse:297.21249
# [639]	train-rmse:264.83255	eval-rmse:297.19998
# [640]	train-rmse:264.77097	eval-rmse:297.19659
# [641]	train-rmse:264.74606	eval-rmse:297.19296
# [642]	train-rmse:264.70053	eval-rmse:297.17145
# [643]	train-rmse:264.68002	eval-rmse:297.18689
# [644]	train-rmse:264.63977	eval-rmse:297.16534
# [645]	train-rmse:264.56897	eval-rmse:297.16013
# [646]	train-rmse:264.54675	eval-rmse:297.16068
# [647]	train-rmse:264.47284	eval-rmse:297.11710
# [648]	train-rmse:264.42566	eval-rmse:297.12613
# [649]	train-rmse:264.41052	eval-rmse:297.12772
# [650]	train-rmse:264.38590	eval-rmse:297.11527
# [651]	train-rmse:264.36475	eval-rmse:297.10385
# [652]	train-rmse:264.22751	eval-rmse:297.08997
# [653]	train-rmse:264.16431	eval-rmse:297.07025
# [654]	train-rmse:264.10474	eval-rmse:297.07245
# [655]	train-rmse:264.08911	eval-rmse:297.06335
# [656]	train-rmse:264.07449	eval-rmse:297.04627
# [657]	train-rmse:264.01587	eval-rmse:297.02246
# [658]	train-rmse:263.98221	eval-rmse:297.02701
# [659]	train-rmse:263.94702	eval-rmse:297.01273
# [660]	train-rmse:263.88998	eval-rmse:297.00925
# [661]	train-rmse:263.85495	eval-rmse:296.99561
# [662]	train-rmse:263.83670	eval-rmse:296.99332
# [663]	train-rmse:263.82742	eval-rmse:296.99533
# [664]	train-rmse:263.76172	eval-rmse:296.96518
# [665]	train-rmse:263.71164	eval-rmse:296.93668
# [666]	train-rmse:263.56396	eval-rmse:296.93347
# [667]	train-rmse:263.51669	eval-rmse:296.94723
# [668]	train-rmse:263.48984	eval-rmse:296.93219
# [669]	train-rmse:263.46756	eval-rmse:296.94055
# [670]	train-rmse:263.45215	eval-rmse:296.93732
# [671]	train-rmse:263.42307	eval-rmse:296.94717
# [672]	train-rmse:263.36182	eval-rmse:296.94217
# [673]	train-rmse:263.33227	eval-rmse:296.93649
# [674]	train-rmse:263.31137	eval-rmse:296.92981
# [675]	train-rmse:263.17539	eval-rmse:296.91147
# [676]	train-rmse:263.13751	eval-rmse:296.90823
# [677]	train-rmse:263.12286	eval-rmse:296.89487
# [678]	train-rmse:263.08231	eval-rmse:296.87964
# [679]	train-rmse:263.04611	eval-rmse:296.87241
# [680]	train-rmse:262.96640	eval-rmse:296.84882
# [681]	train-rmse:262.90518	eval-rmse:296.79840
# [682]	train-rmse:262.82587	eval-rmse:296.81613
# [683]	train-rmse:262.75619	eval-rmse:296.78696
# [684]	train-rmse:262.68527	eval-rmse:296.76599
# [685]	train-rmse:262.66275	eval-rmse:296.77576
# [686]	train-rmse:262.53915	eval-rmse:296.71375
# [687]	train-rmse:262.48193	eval-rmse:296.67838
# [688]	train-rmse:262.44809	eval-rmse:296.67761
# [689]	train-rmse:262.42642	eval-rmse:296.68225
# [690]	train-rmse:262.41046	eval-rmse:296.68417
# [691]	train-rmse:262.36725	eval-rmse:296.67557
# [692]	train-rmse:262.30594	eval-rmse:296.64313
# [693]	train-rmse:262.18298	eval-rmse:296.58225
# [694]	train-rmse:262.11157	eval-rmse:296.60523
# [695]	train-rmse:262.07980	eval-rmse:296.57083
# [696]	train-rmse:262.05713	eval-rmse:296.58105
# [697]	train-rmse:262.02924	eval-rmse:296.57257
# [698]	train-rmse:261.95200	eval-rmse:296.55298
# [699]	train-rmse:261.85352	eval-rmse:296.54953
# [700]	train-rmse:261.78708	eval-rmse:296.55807
# [701]	train-rmse:261.71341	eval-rmse:296.54559
# [702]	train-rmse:261.68286	eval-rmse:296.52768
# [703]	train-rmse:261.54459	eval-rmse:296.49979
# [704]	train-rmse:261.50494	eval-rmse:296.50714
# [705]	train-rmse:261.48184	eval-rmse:296.48496
# [706]	train-rmse:261.45624	eval-rmse:296.48309
# [707]	train-rmse:261.40268	eval-rmse:296.43588
# [708]	train-rmse:261.35074	eval-rmse:296.45966
# [709]	train-rmse:261.29150	eval-rmse:296.43146
# [710]	train-rmse:261.25742	eval-rmse:296.43112
# [711]	train-rmse:261.22986	eval-rmse:296.42047
# [712]	train-rmse:261.21295	eval-rmse:296.41925
# [713]	train-rmse:261.19519	eval-rmse:296.42450
# [714]	train-rmse:261.15378	eval-rmse:296.44336
# [715]	train-rmse:261.10730	eval-rmse:296.42670
# [716]	train-rmse:261.09073	eval-rmse:296.42874
# [717]	train-rmse:261.06399	eval-rmse:296.42575
# [718]	train-rmse:261.05493	eval-rmse:296.42224
# [719]	train-rmse:261.02588	eval-rmse:296.41290
# [720]	train-rmse:261.01837	eval-rmse:296.39703
# [721]	train-rmse:260.96314	eval-rmse:296.36487
# [722]	train-rmse:260.93716	eval-rmse:296.34818
# [723]	train-rmse:260.90137	eval-rmse:296.34634
# [724]	train-rmse:260.88782	eval-rmse:296.35767
# [725]	train-rmse:260.80212	eval-rmse:296.31476
# [726]	train-rmse:260.79169	eval-rmse:296.31668
# [727]	train-rmse:260.76910	eval-rmse:296.32178
# [728]	train-rmse:260.74994	eval-rmse:296.30225
# [729]	train-rmse:260.73160	eval-rmse:296.29529
# [730]	train-rmse:260.68753	eval-rmse:296.27969
# [731]	train-rmse:260.66516	eval-rmse:296.26709
# [732]	train-rmse:260.63013	eval-rmse:296.28870
# [733]	train-rmse:260.61545	eval-rmse:296.29434
# [734]	train-rmse:260.59619	eval-rmse:296.28995
# [735]	train-rmse:260.54660	eval-rmse:296.28217
# [736]	train-rmse:260.45242	eval-rmse:296.21280
# [737]	train-rmse:260.39887	eval-rmse:296.19733
# [738]	train-rmse:260.37824	eval-rmse:296.19138
# [739]	train-rmse:260.30493	eval-rmse:296.17465
# [740]	train-rmse:260.29117	eval-rmse:296.17258
# [741]	train-rmse:260.26544	eval-rmse:296.16815
# [742]	train-rmse:260.20486	eval-rmse:296.19522
# [743]	train-rmse:260.11737	eval-rmse:296.21188
# [744]	train-rmse:260.03778	eval-rmse:296.17905
# [745]	train-rmse:259.97592	eval-rmse:296.15198
# [746]	train-rmse:259.96005	eval-rmse:296.15253
# [747]	train-rmse:259.91934	eval-rmse:296.18109
# [748]	train-rmse:259.88596	eval-rmse:296.18143
# [749]	train-rmse:259.87122	eval-rmse:296.17679
# [750]	train-rmse:259.85028	eval-rmse:296.17154
# [751]	train-rmse:259.80566	eval-rmse:296.19513
# [752]	train-rmse:259.77307	eval-rmse:296.18088
# [753]	train-rmse:259.67673	eval-rmse:296.14764
# [754]	train-rmse:259.60858	eval-rmse:296.13180
# [755]	train-rmse:259.59271	eval-rmse:296.11542
# [756]	train-rmse:259.46918	eval-rmse:296.09998
# [757]	train-rmse:259.41458	eval-rmse:296.05402
# [758]	train-rmse:259.33310	eval-rmse:296.01852
# [759]	train-rmse:259.31848	eval-rmse:296.00629
# [760]	train-rmse:259.28799	eval-rmse:295.98966
# [761]	train-rmse:259.25906	eval-rmse:295.95648
# [762]	train-rmse:259.19769	eval-rmse:295.92529
# [763]	train-rmse:259.18527	eval-rmse:295.92621
# [764]	train-rmse:259.17313	eval-rmse:295.93475
# [765]	train-rmse:259.10584	eval-rmse:295.92010
# [766]	train-rmse:259.08344	eval-rmse:295.90832
# [767]	train-rmse:259.06622	eval-rmse:295.89889
# [768]	train-rmse:258.97800	eval-rmse:295.86362
# [769]	train-rmse:258.94733	eval-rmse:295.86047
# [770]	train-rmse:258.93487	eval-rmse:295.85156
# [771]	train-rmse:258.92743	eval-rmse:295.86020
# [772]	train-rmse:258.86044	eval-rmse:295.86020
# [773]	train-rmse:258.82782	eval-rmse:295.85989
# [774]	train-rmse:258.74826	eval-rmse:295.83667
# [775]	train-rmse:258.72348	eval-rmse:295.81216
# [776]	train-rmse:258.67181	eval-rmse:295.78400
# [777]	train-rmse:258.64499	eval-rmse:295.76761
# [778]	train-rmse:258.60223	eval-rmse:295.75400
# [779]	train-rmse:258.56549	eval-rmse:295.74744
# [780]	train-rmse:258.49689	eval-rmse:295.72226
# [781]	train-rmse:258.48743	eval-rmse:295.71942
# [782]	train-rmse:258.48294	eval-rmse:295.71628
# [783]	train-rmse:258.36865	eval-rmse:295.68307
# [784]	train-rmse:258.29517	eval-rmse:295.66989
# [785]	train-rmse:258.23337	eval-rmse:295.64346
# [786]	train-rmse:258.18964	eval-rmse:295.62582
# [787]	train-rmse:258.13846	eval-rmse:295.59567
# [788]	train-rmse:258.06863	eval-rmse:295.55811
# [789]	train-rmse:258.05463	eval-rmse:295.55188
# [790]	train-rmse:257.99515	eval-rmse:295.52918
# [791]	train-rmse:257.97903	eval-rmse:295.52701
# [792]	train-rmse:257.93002	eval-rmse:295.50943
# [793]	train-rmse:257.84775	eval-rmse:295.48300
# [794]	train-rmse:257.80707	eval-rmse:295.47284
# [795]	train-rmse:257.78574	eval-rmse:295.47000
# [796]	train-rmse:257.77454	eval-rmse:295.46823
# [797]	train-rmse:257.74542	eval-rmse:295.45465
# [798]	train-rmse:257.73862	eval-rmse:295.46490
# [799]	train-rmse:257.70267	eval-rmse:295.45621
# [800]	train-rmse:257.65231	eval-rmse:295.42206
# [801]	train-rmse:257.62723	eval-rmse:295.41812
# [802]	train-rmse:257.57816	eval-rmse:295.41217
# [803]	train-rmse:257.55966	eval-rmse:295.39978
# [804]	train-rmse:257.47943	eval-rmse:295.36645
# [805]	train-rmse:257.43182	eval-rmse:295.36383
# [806]	train-rmse:257.37766	eval-rmse:295.33490
# [807]	train-rmse:257.33032	eval-rmse:295.30963
# [808]	train-rmse:257.31015	eval-rmse:295.30420
# [809]	train-rmse:257.29544	eval-rmse:295.31082
# [810]	train-rmse:257.26291	eval-rmse:295.30426
# [811]	train-rmse:257.25980	eval-rmse:295.30029
# [812]	train-rmse:257.23300	eval-rmse:295.31445
# [813]	train-rmse:257.18072	eval-rmse:295.28735
# [814]	train-rmse:257.17316	eval-rmse:295.29407
# [815]	train-rmse:257.15860	eval-rmse:295.29358
# [816]	train-rmse:257.10443	eval-rmse:295.25977
# [817]	train-rmse:257.09683	eval-rmse:295.25787
# [818]	train-rmse:257.08896	eval-rmse:295.24258
# [819]	train-rmse:257.05606	eval-rmse:295.24448
# [820]	train-rmse:257.00973	eval-rmse:295.20850
# [821]	train-rmse:256.95386	eval-rmse:295.18826
# [822]	train-rmse:256.93494	eval-rmse:295.18628
# [823]	train-rmse:256.93356	eval-rmse:295.18405
# [824]	train-rmse:256.92304	eval-rmse:295.19269
# [825]	train-rmse:256.90515	eval-rmse:295.19842
# [826]	train-rmse:256.88943	eval-rmse:295.20233
# [827]	train-rmse:256.85181	eval-rmse:295.17932
# [828]	train-rmse:256.82156	eval-rmse:295.16547
# [829]	train-rmse:256.82040	eval-rmse:295.16321
# [830]	train-rmse:256.79608	eval-rmse:295.15903
# [831]	train-rmse:256.78256	eval-rmse:295.15921
# [832]	train-rmse:256.77908	eval-rmse:295.15506
# [833]	train-rmse:256.72894	eval-rmse:295.14600
# [834]	train-rmse:256.70154	eval-rmse:295.13797
# [835]	train-rmse:256.69650	eval-rmse:295.13824
# [836]	train-rmse:256.69074	eval-rmse:295.14218
# [837]	train-rmse:256.65161	eval-rmse:295.10803
# [838]	train-rmse:256.64551	eval-rmse:295.09921
# [839]	train-rmse:256.62869	eval-rmse:295.09216
# [840]	train-rmse:256.62027	eval-rmse:295.08624
# [841]	train-rmse:256.59305	eval-rmse:295.09680
# [842]	train-rmse:256.56360	eval-rmse:295.07251
# [843]	train-rmse:256.51431	eval-rmse:295.04205
# [844]	train-rmse:256.49084	eval-rmse:295.03976
# [845]	train-rmse:256.46628	eval-rmse:295.04108
# [846]	train-rmse:256.41174	eval-rmse:295.03070
# [847]	train-rmse:256.40301	eval-rmse:295.03122
# [848]	train-rmse:256.38882	eval-rmse:295.04355
# [849]	train-rmse:256.36478	eval-rmse:295.05197
# [850]	train-rmse:256.32223	eval-rmse:295.03442
# [851]	train-rmse:256.29053	eval-rmse:295.04440
# [852]	train-rmse:256.27063	eval-rmse:295.02771
# [853]	train-rmse:256.23871	eval-rmse:295.02206
# [854]	train-rmse:256.16647	eval-rmse:294.99774
# [855]	train-rmse:256.10184	eval-rmse:294.94678
# [856]	train-rmse:256.07410	eval-rmse:294.93683
# [857]	train-rmse:256.03799	eval-rmse:294.93445
# [858]	train-rmse:256.01193	eval-rmse:294.92731
# [859]	train-rmse:255.98161	eval-rmse:294.92831
# [860]	train-rmse:255.95032	eval-rmse:294.89642
# [861]	train-rmse:255.88261	eval-rmse:294.86764
# [862]	train-rmse:255.86942	eval-rmse:294.86783
# [863]	train-rmse:255.85593	eval-rmse:294.85751
# [864]	train-rmse:255.81426	eval-rmse:294.84091
# [865]	train-rmse:255.77263	eval-rmse:294.81403
# [866]	train-rmse:255.73795	eval-rmse:294.79465
# [867]	train-rmse:255.69835	eval-rmse:294.77884
# [868]	train-rmse:255.69095	eval-rmse:294.78693
# [869]	train-rmse:255.68565	eval-rmse:294.79840
# [870]	train-rmse:255.64996	eval-rmse:294.79437
# [871]	train-rmse:255.63867	eval-rmse:294.79163
# [872]	train-rmse:255.63048	eval-rmse:294.78732
# [873]	train-rmse:255.60661	eval-rmse:294.76477
# [874]	train-rmse:255.55942	eval-rmse:294.74564
# [875]	train-rmse:255.53607	eval-rmse:294.73187
# [876]	train-rmse:255.51764	eval-rmse:294.72443
# [877]	train-rmse:255.49115	eval-rmse:294.71582
# [878]	train-rmse:255.45053	eval-rmse:294.71411
# [879]	train-rmse:255.43549	eval-rmse:294.71338
# [880]	train-rmse:255.40437	eval-rmse:294.68701
# [881]	train-rmse:255.37651	eval-rmse:294.72540
# [882]	train-rmse:255.34030	eval-rmse:294.71606
# [883]	train-rmse:255.32851	eval-rmse:294.73230
# [884]	train-rmse:255.31792	eval-rmse:294.71573
# [885]	train-rmse:255.31638	eval-rmse:294.71387
# [886]	train-rmse:255.30562	eval-rmse:294.71420
# [887]	train-rmse:255.29988	eval-rmse:294.70685
# [888]	train-rmse:255.28105	eval-rmse:294.69641
# [889]	train-rmse:255.27016	eval-rmse:294.69525
# [890]	train-rmse:255.25107	eval-rmse:294.67017
# [891]	train-rmse:255.18069	eval-rmse:294.65472
# [892]	train-rmse:255.16235	eval-rmse:294.64877
# [893]	train-rmse:255.11911	eval-rmse:294.66702
# [894]	train-rmse:255.10373	eval-rmse:294.65936
# [895]	train-rmse:255.09686	eval-rmse:294.64893
# [896]	train-rmse:255.07622	eval-rmse:294.63800
# [897]	train-rmse:255.06424	eval-rmse:294.63135
# [898]	train-rmse:255.06174	eval-rmse:294.62607
# [899]	train-rmse:255.01154	eval-rmse:294.63669
# [900]	train-rmse:254.99892	eval-rmse:294.64374
# [901]	train-rmse:254.98796	eval-rmse:294.63922
# [902]	train-rmse:254.97757	eval-rmse:294.64127
# [903]	train-rmse:254.95283	eval-rmse:294.64603
# [904]	train-rmse:254.92680	eval-rmse:294.62338
# [905]	train-rmse:254.90753	eval-rmse:294.60648
# [906]	train-rmse:254.88298	eval-rmse:294.61960
# [907]	train-rmse:254.82065	eval-rmse:294.59363
# [908]	train-rmse:254.79874	eval-rmse:294.59070
# [909]	train-rmse:254.78239	eval-rmse:294.58066
# [910]	train-rmse:254.72700	eval-rmse:294.56467
# [911]	train-rmse:254.68771	eval-rmse:294.55435
# [912]	train-rmse:254.63535	eval-rmse:294.46020
# [913]	train-rmse:254.61112	eval-rmse:294.46137
# [914]	train-rmse:254.60684	eval-rmse:294.45148
# [915]	train-rmse:254.57147	eval-rmse:294.41510
# [916]	train-rmse:254.54750	eval-rmse:294.40634
# [917]	train-rmse:254.52747	eval-rmse:294.41498
# [918]	train-rmse:254.47496	eval-rmse:294.38422
# [919]	train-rmse:254.44487	eval-rmse:294.37518
# [920]	train-rmse:254.43167	eval-rmse:294.37289
# [921]	train-rmse:254.39996	eval-rmse:294.36136
# [922]	train-rmse:254.39651	eval-rmse:294.34607
# [923]	train-rmse:254.35315	eval-rmse:294.34296
# [924]	train-rmse:254.31450	eval-rmse:294.34311
# [925]	train-rmse:254.28290	eval-rmse:294.31335
# [926]	train-rmse:254.25439	eval-rmse:294.30112
# [927]	train-rmse:254.18314	eval-rmse:294.27411
# [928]	train-rmse:254.17294	eval-rmse:294.26700
# [929]	train-rmse:254.15193	eval-rmse:294.25629
# [930]	train-rmse:254.12149	eval-rmse:294.26294
# [931]	train-rmse:254.11092	eval-rmse:294.26459
# [932]	train-rmse:254.09453	eval-rmse:294.25314
# [933]	train-rmse:254.07224	eval-rmse:294.24097
# [934]	train-rmse:254.03311	eval-rmse:294.22855
# [935]	train-rmse:254.00748	eval-rmse:294.21753
# [936]	train-rmse:253.99069	eval-rmse:294.20407
# [937]	train-rmse:253.95016	eval-rmse:294.18466
# [938]	train-rmse:253.91882	eval-rmse:294.18408
# [939]	train-rmse:253.90620	eval-rmse:294.18219
# [940]	train-rmse:253.90149	eval-rmse:294.17880
# [941]	train-rmse:253.89873	eval-rmse:294.17804
# [942]	train-rmse:253.89288	eval-rmse:294.16611
# [943]	train-rmse:253.87547	eval-rmse:294.15796
# [944]	train-rmse:253.86491	eval-rmse:294.15195
# [945]	train-rmse:253.82960	eval-rmse:294.11343
# [946]	train-rmse:253.80939	eval-rmse:294.11136
# [947]	train-rmse:253.80337	eval-rmse:294.10391
# [948]	train-rmse:253.80000	eval-rmse:294.09418
# [949]	train-rmse:253.77989	eval-rmse:294.08841
# [950]	train-rmse:253.77331	eval-rmse:294.09161
# [951]	train-rmse:253.73483	eval-rmse:294.09610
# [952]	train-rmse:253.67517	eval-rmse:294.10821
# [953]	train-rmse:253.66884	eval-rmse:294.10419
# [954]	train-rmse:253.63557	eval-rmse:294.11026
# [955]	train-rmse:253.59992	eval-rmse:294.11963
# [956]	train-rmse:253.59042	eval-rmse:294.11414
# [957]	train-rmse:253.57550	eval-rmse:294.11096
# [958]	train-rmse:253.54460	eval-rmse:294.10141
# [959]	train-rmse:253.50412	eval-rmse:294.10266
# [13:32:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:32:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-rmse:3332.88965	eval-rmse:3391.43066
# [1]	train-rmse:3008.67358	eval-rmse:3072.41284
# [2]	train-rmse:2717.29517	eval-rmse:2787.51025
# [3]	train-rmse:2455.13306	eval-rmse:2532.46899
# [4]	train-rmse:2219.54614	eval-rmse:2305.13232
# [5]	train-rmse:2007.78564	eval-rmse:2102.06372
# [6]	train-rmse:1817.54077	eval-rmse:1920.47522
# [7]	train-rmse:1646.68262	eval-rmse:1760.01538
# [8]	train-rmse:1493.39575	eval-rmse:1617.64624
# [9]	train-rmse:1356.40454	eval-rmse:1491.62170
# [10]	train-rmse:1233.34241	eval-rmse:1380.77917
# [11]	train-rmse:1123.19556	eval-rmse:1282.85608
# [12]	train-rmse:1024.53284	eval-rmse:1196.66443
# [13]	train-rmse:936.33246	eval-rmse:1121.66333
# [14]	train-rmse:858.21375	eval-rmse:1057.86755
# [15]	train-rmse:788.27356	eval-rmse:1001.45477
# [16]	train-rmse:726.06653	eval-rmse:953.63806
# [17]	train-rmse:671.25897	eval-rmse:913.29224
# [18]	train-rmse:622.25061	eval-rmse:877.25336
# [19]	train-rmse:579.73468	eval-rmse:847.76819
# [20]	train-rmse:542.06555	eval-rmse:822.22235
# [21]	train-rmse:509.42709	eval-rmse:801.19940
# [22]	train-rmse:480.43610	eval-rmse:783.32410
# [23]	train-rmse:454.73828	eval-rmse:768.01910
# [24]	train-rmse:432.59317	eval-rmse:755.29352
# [25]	train-rmse:412.64789	eval-rmse:744.35608
# [26]	train-rmse:396.17304	eval-rmse:735.67664
# [27]	train-rmse:381.65012	eval-rmse:728.23456
# [28]	train-rmse:368.86191	eval-rmse:722.04224
# [29]	train-rmse:357.85141	eval-rmse:716.57959
# [30]	train-rmse:348.65442	eval-rmse:712.24622
# [31]	train-rmse:340.21545	eval-rmse:708.20904
# [32]	train-rmse:333.18701	eval-rmse:704.92377
# [33]	train-rmse:327.29379	eval-rmse:701.98541
# [34]	train-rmse:322.21378	eval-rmse:699.94696
# [35]	train-rmse:317.51270	eval-rmse:697.97333
# [36]	train-rmse:313.38504	eval-rmse:696.24664
# [37]	train-rmse:309.66449	eval-rmse:694.49408
# [38]	train-rmse:306.47510	eval-rmse:692.89130
# ...
# [503]	train-rmse:274.35446	eval-rmse:321.12842
# [504]	train-rmse:274.28805	eval-rmse:321.09226
# [505]	train-rmse:274.24072	eval-rmse:321.08353
# [506]	train-rmse:274.21454	eval-rmse:321.08728
# [507]	train-rmse:274.05417	eval-rmse:320.99930
# [508]	train-rmse:273.97922	eval-rmse:320.96896
# [509]	train-rmse:273.96652	eval-rmse:320.96115
# [510]	train-rmse:273.87137	eval-rmse:320.91327
# [511]	train-rmse:273.82312	eval-rmse:320.88126
# [512]	train-rmse:273.74701	eval-rmse:320.85135
# [513]	train-rmse:273.73239	eval-rmse:320.85242
# [514]	train-rmse:273.63385	eval-rmse:320.82269
# [515]	train-rmse:273.55002	eval-rmse:320.80402
# [516]	train-rmse:273.50336	eval-rmse:320.78671
# [517]	train-rmse:273.35956	eval-rmse:320.72183
# [518]	train-rmse:273.27127	eval-rmse:320.68417
# [519]	train-rmse:273.23035	eval-rmse:320.68710
# [520]	train-rmse:273.15301	eval-rmse:320.65503
# [521]	train-rmse:273.00842	eval-rmse:320.62430
# [522]	train-rmse:272.82376	eval-rmse:320.56418
# [523]	train-rmse:272.73398	eval-rmse:320.49304
# [524]	train-rmse:272.71298	eval-rmse:320.51126
# [525]	train-rmse:272.60925	eval-rmse:320.50015
# [526]	train-rmse:272.59238	eval-rmse:320.48874
# [527]	train-rmse:272.50742	eval-rmse:320.43762
# [528]	train-rmse:272.44363	eval-rmse:320.41830
# [529]	train-rmse:272.32001	eval-rmse:320.42200
# [530]	train-rmse:272.25937	eval-rmse:320.40689
# [531]	train-rmse:272.22232	eval-rmse:320.42053
# [532]	train-rmse:272.02527	eval-rmse:320.30637
# [533]	train-rmse:272.00586	eval-rmse:320.29205
# [534]	train-rmse:271.99731	eval-rmse:320.28217
# [535]	train-rmse:271.87201	eval-rmse:320.23447
# [536]	train-rmse:271.84622	eval-rmse:320.23383
# [537]	train-rmse:271.79559	eval-rmse:320.23111
# [538]	train-rmse:271.73062	eval-rmse:320.21609
# [539]	train-rmse:271.66940	eval-rmse:320.17401
# [540]	train-rmse:271.53558	eval-rmse:320.08478
# [541]	train-rmse:271.44833	eval-rmse:320.02194
# [542]	train-rmse:271.29080	eval-rmse:319.95529
# [543]	train-rmse:271.22604	eval-rmse:319.95917
# [544]	train-rmse:271.16602	eval-rmse:319.90588
# [545]	train-rmse:271.10345	eval-rmse:319.90006
# [546]	train-rmse:271.09320	eval-rmse:319.88779
# [547]	train-rmse:271.04269	eval-rmse:319.88232
# [548]	train-rmse:270.98285	eval-rmse:319.87262
# [549]	train-rmse:270.96124	eval-rmse:319.87546
# [550]	train-rmse:270.94009	eval-rmse:319.90866
# [551]	train-rmse:270.90344	eval-rmse:319.87567
# [552]	train-rmse:270.83051	eval-rmse:319.88110
# [553]	train-rmse:270.76221	eval-rmse:319.86841
# [554]	train-rmse:270.72018	eval-rmse:319.85001
# [555]	train-rmse:270.66098	eval-rmse:319.84222
# [556]	train-rmse:270.55191	eval-rmse:319.77020
# [557]	train-rmse:270.53732	eval-rmse:319.77017
# [558]	train-rmse:270.50882	eval-rmse:319.76355
# [559]	train-rmse:270.48520	eval-rmse:319.75855
# [560]	train-rmse:270.37692	eval-rmse:319.74039
# [561]	train-rmse:270.28305	eval-rmse:319.74271
# [562]	train-rmse:270.24936	eval-rmse:319.74933
# [563]	train-rmse:270.19980	eval-rmse:319.73410
# [564]	train-rmse:270.15836	eval-rmse:319.72076
# [565]	train-rmse:270.15607	eval-rmse:319.72040
# [566]	train-rmse:270.04074	eval-rmse:319.65924
# [567]	train-rmse:269.86447	eval-rmse:319.59576
# [568]	train-rmse:269.77799	eval-rmse:319.58344
# [569]	train-rmse:269.75256	eval-rmse:319.54483
# [570]	train-rmse:269.70386	eval-rmse:319.53345
# [571]	train-rmse:269.67017	eval-rmse:319.52438
# [572]	train-rmse:269.63626	eval-rmse:319.52914
# [573]	train-rmse:269.61621	eval-rmse:319.53537
# [574]	train-rmse:269.59634	eval-rmse:319.50540
# [575]	train-rmse:269.48959	eval-rmse:319.47150
# [576]	train-rmse:269.44894	eval-rmse:319.47641
# [577]	train-rmse:269.43424	eval-rmse:319.48239
# [578]	train-rmse:269.43231	eval-rmse:319.48172
# [579]	train-rmse:269.34235	eval-rmse:319.45770
# [580]	train-rmse:269.28217	eval-rmse:319.44977
# [581]	train-rmse:269.17532	eval-rmse:319.39533
# [582]	train-rmse:269.11697	eval-rmse:319.39331
# [583]	train-rmse:269.06757	eval-rmse:319.38617
# [584]	train-rmse:269.00235	eval-rmse:319.33566
# [585]	train-rmse:268.95273	eval-rmse:319.33197
# [586]	train-rmse:268.90692	eval-rmse:319.32404
# [587]	train-rmse:268.88089	eval-rmse:319.30139
# [588]	train-rmse:268.80231	eval-rmse:319.27451
# [589]	train-rmse:268.75702	eval-rmse:319.27106
# [590]	train-rmse:268.73245	eval-rmse:319.28851
# [591]	train-rmse:268.73007	eval-rmse:319.28619
# [592]	train-rmse:268.71365	eval-rmse:319.25278
# [593]	train-rmse:268.69159	eval-rmse:319.24185
# [594]	train-rmse:268.59170	eval-rmse:319.27759
# [595]	train-rmse:268.54352	eval-rmse:319.26019
# [596]	train-rmse:268.46274	eval-rmse:319.25244
# [597]	train-rmse:268.43210	eval-rmse:319.23782
# [598]	train-rmse:268.35821	eval-rmse:319.25494
# [599]	train-rmse:268.24612	eval-rmse:319.23752
# [600]	train-rmse:268.23703	eval-rmse:319.23618
# [601]	train-rmse:268.18430	eval-rmse:319.21408
# [602]	train-rmse:268.11301	eval-rmse:319.19784
# [603]	train-rmse:268.08267	eval-rmse:319.21616
# [604]	train-rmse:267.97922	eval-rmse:319.15216
# [605]	train-rmse:267.95181	eval-rmse:319.14594
# [606]	train-rmse:267.84741	eval-rmse:319.04837
# [607]	train-rmse:267.77106	eval-rmse:319.03894
# [608]	train-rmse:267.74417	eval-rmse:319.04202
# [609]	train-rmse:267.62524	eval-rmse:318.96085
# [610]	train-rmse:267.61502	eval-rmse:318.95215
# [611]	train-rmse:267.55945	eval-rmse:318.96390
# [612]	train-rmse:267.54974	eval-rmse:318.96060
# [613]	train-rmse:267.50409	eval-rmse:318.92502
# [614]	train-rmse:267.46616	eval-rmse:318.91846
# [615]	train-rmse:267.33814	eval-rmse:318.85400
# [616]	train-rmse:267.30847	eval-rmse:318.87219
# [617]	train-rmse:267.10406	eval-rmse:318.82178
# [618]	train-rmse:267.04971	eval-rmse:318.78375
# [619]	train-rmse:266.94232	eval-rmse:318.71973
# [620]	train-rmse:266.86182	eval-rmse:318.70013
# [621]	train-rmse:266.77799	eval-rmse:318.62463
# [622]	train-rmse:266.73468	eval-rmse:318.61536
# [623]	train-rmse:266.70862	eval-rmse:318.59790
# [624]	train-rmse:266.69833	eval-rmse:318.59131
# [625]	train-rmse:266.63635	eval-rmse:318.56162
# [626]	train-rmse:266.59641	eval-rmse:318.53760
# [627]	train-rmse:266.54999	eval-rmse:318.53336
# [628]	train-rmse:266.45239	eval-rmse:318.52475
# [629]	train-rmse:266.43356	eval-rmse:318.52045
# [630]	train-rmse:266.42310	eval-rmse:318.52142
# [631]	train-rmse:266.35532	eval-rmse:318.48117
# [632]	train-rmse:266.32526	eval-rmse:318.46729
# [633]	train-rmse:266.31882	eval-rmse:318.47086
# [634]	train-rmse:266.26163	eval-rmse:318.45035
# [635]	train-rmse:266.18597	eval-rmse:318.41025
# [636]	train-rmse:266.17142	eval-rmse:318.39957
# [637]	train-rmse:266.12872	eval-rmse:318.37543
# [638]	train-rmse:266.11444	eval-rmse:318.37588
# [639]	train-rmse:265.97830	eval-rmse:318.28421
# [640]	train-rmse:265.91864	eval-rmse:318.24899
# [641]	train-rmse:265.79758	eval-rmse:318.20612
# [642]	train-rmse:265.78210	eval-rmse:318.20270
# [643]	train-rmse:265.71536	eval-rmse:318.12320
# [644]	train-rmse:265.69156	eval-rmse:318.11172
# [645]	train-rmse:265.66779	eval-rmse:318.08756
# [646]	train-rmse:265.60568	eval-rmse:318.07864
# [647]	train-rmse:265.52454	eval-rmse:318.03485
# [648]	train-rmse:265.51196	eval-rmse:318.02530
# [649]	train-rmse:265.45059	eval-rmse:318.00235
# [650]	train-rmse:265.40967	eval-rmse:318.01270
# [651]	train-rmse:265.36749	eval-rmse:317.95053
# [652]	train-rmse:265.34412	eval-rmse:317.95551
# [653]	train-rmse:265.33426	eval-rmse:317.96518
# [654]	train-rmse:265.30139	eval-rmse:317.94940
# [655]	train-rmse:265.22052	eval-rmse:317.91544
# [656]	train-rmse:265.08093	eval-rmse:317.84271
# [657]	train-rmse:265.07156	eval-rmse:317.83225
# [658]	train-rmse:264.98993	eval-rmse:317.82108
# [659]	train-rmse:264.89441	eval-rmse:317.76831
# [660]	train-rmse:264.83414	eval-rmse:317.74579
# [661]	train-rmse:264.71716	eval-rmse:317.67999
# [662]	train-rmse:264.63592	eval-rmse:317.66635
# [663]	train-rmse:264.62854	eval-rmse:317.66068
# [664]	train-rmse:264.54001	eval-rmse:317.65988
# [665]	train-rmse:264.44302	eval-rmse:317.57288
# [666]	train-rmse:264.38943	eval-rmse:317.55924
# [667]	train-rmse:264.27948	eval-rmse:317.52286
# [668]	train-rmse:264.17825	eval-rmse:317.48398
# [669]	train-rmse:264.04068	eval-rmse:317.37546
# [670]	train-rmse:263.99322	eval-rmse:317.36420
# [671]	train-rmse:263.97665	eval-rmse:317.33496
# [672]	train-rmse:263.94019	eval-rmse:317.32461
# [673]	train-rmse:263.85361	eval-rmse:317.26392
# [674]	train-rmse:263.81516	eval-rmse:317.24509
# [675]	train-rmse:263.75827	eval-rmse:317.21149
# [676]	train-rmse:263.75015	eval-rmse:317.20758
# [677]	train-rmse:263.68930	eval-rmse:317.19278
# [678]	train-rmse:263.65201	eval-rmse:317.17514
# [679]	train-rmse:263.62396	eval-rmse:317.16217
# [680]	train-rmse:263.59683	eval-rmse:317.14569
# [681]	train-rmse:263.52667	eval-rmse:317.11273
# [682]	train-rmse:263.51416	eval-rmse:317.10202
# [683]	train-rmse:263.44690	eval-rmse:317.07037
# [684]	train-rmse:263.43265	eval-rmse:317.06357
# [685]	train-rmse:263.41812	eval-rmse:317.06891
# [686]	train-rmse:263.40973	eval-rmse:317.06567
# [687]	train-rmse:263.39932	eval-rmse:317.05862
# [688]	train-rmse:263.33496	eval-rmse:317.04819
# [689]	train-rmse:263.27591	eval-rmse:317.01968
# [690]	train-rmse:263.18121	eval-rmse:316.97311
# [691]	train-rmse:263.16486	eval-rmse:316.96854
# [692]	train-rmse:263.15088	eval-rmse:316.97293
# [693]	train-rmse:263.12451	eval-rmse:316.95868
# [694]	train-rmse:262.99930	eval-rmse:316.93961
# [695]	train-rmse:262.96350	eval-rmse:316.91614
# [696]	train-rmse:262.90836	eval-rmse:316.89535
# [697]	train-rmse:262.85846	eval-rmse:316.92953
# [698]	train-rmse:262.85053	eval-rmse:316.93573
# [699]	train-rmse:262.79217	eval-rmse:316.91052
# [700]	train-rmse:262.73914	eval-rmse:316.89459
# [701]	train-rmse:262.72659	eval-rmse:316.89658
# [702]	train-rmse:262.70050	eval-rmse:316.87610
# [703]	train-rmse:262.65418	eval-rmse:316.86459
# [704]	train-rmse:262.63242	eval-rmse:316.85556
# [705]	train-rmse:262.61398	eval-rmse:316.85165
# [706]	train-rmse:262.61261	eval-rmse:316.85092
# [707]	train-rmse:262.61081	eval-rmse:316.85028
# [708]	train-rmse:262.56311	eval-rmse:316.83444
# [709]	train-rmse:262.55051	eval-rmse:316.83795
# [710]	train-rmse:262.54248	eval-rmse:316.83981
# [711]	train-rmse:262.52454	eval-rmse:316.83719
# [712]	train-rmse:262.38840	eval-rmse:316.80978
# [713]	train-rmse:262.30783	eval-rmse:316.81973
# [714]	train-rmse:262.24374	eval-rmse:316.76819
# [715]	train-rmse:262.17102	eval-rmse:316.73395
# [716]	train-rmse:262.06796	eval-rmse:316.70535
# [717]	train-rmse:262.03442	eval-rmse:316.70828
# [718]	train-rmse:261.98831	eval-rmse:316.66699
# [719]	train-rmse:261.90677	eval-rmse:316.62146
# [720]	train-rmse:261.86978	eval-rmse:316.59082
# [721]	train-rmse:261.85556	eval-rmse:316.58038
# [722]	train-rmse:261.81253	eval-rmse:316.55102
# [723]	train-rmse:261.74921	eval-rmse:316.51334
# [724]	train-rmse:261.72458	eval-rmse:316.50766
# [725]	train-rmse:261.62418	eval-rmse:316.49466
# [726]	train-rmse:261.54730	eval-rmse:316.48563
# [727]	train-rmse:261.51065	eval-rmse:316.46106
# [728]	train-rmse:261.47263	eval-rmse:316.45065
# [729]	train-rmse:261.39591	eval-rmse:316.38123
# [730]	train-rmse:261.36594	eval-rmse:316.35507
# [731]	train-rmse:261.33969	eval-rmse:316.34726
# [732]	train-rmse:261.28586	eval-rmse:316.36957
# [733]	train-rmse:261.24030	eval-rmse:316.35202
# [734]	train-rmse:261.23682	eval-rmse:316.34879
# [735]	train-rmse:261.21097	eval-rmse:316.34515
# [736]	train-rmse:261.12961	eval-rmse:316.29108
# [737]	train-rmse:261.12247	eval-rmse:316.30750
# [738]	train-rmse:261.08716	eval-rmse:316.29788
# [739]	train-rmse:261.05936	eval-rmse:316.28479
# [740]	train-rmse:261.01111	eval-rmse:316.28882
# [741]	train-rmse:260.99997	eval-rmse:316.27954
# [742]	train-rmse:260.88135	eval-rmse:316.26581
# [743]	train-rmse:260.82550	eval-rmse:316.24719
# [744]	train-rmse:260.78195	eval-rmse:316.24881
# [745]	train-rmse:260.71906	eval-rmse:316.21692
# [746]	train-rmse:260.62567	eval-rmse:316.18686
# [747]	train-rmse:260.57614	eval-rmse:316.18115
# [748]	train-rmse:260.52557	eval-rmse:316.19016
# [749]	train-rmse:260.49307	eval-rmse:316.19849
# [750]	train-rmse:260.40259	eval-rmse:316.17325
# [751]	train-rmse:260.34778	eval-rmse:316.14584
# [752]	train-rmse:260.31906	eval-rmse:316.13254
# [753]	train-rmse:260.24399	eval-rmse:316.13803
# [754]	train-rmse:260.17541	eval-rmse:316.11865
# [755]	train-rmse:260.10770	eval-rmse:316.12384
# [756]	train-rmse:260.02988	eval-rmse:316.12369
# [757]	train-rmse:260.01459	eval-rmse:316.12921
# [758]	train-rmse:259.98880	eval-rmse:316.10031
# [759]	train-rmse:259.93625	eval-rmse:316.08856
# [760]	train-rmse:259.91113	eval-rmse:316.08536
# [761]	train-rmse:259.87424	eval-rmse:316.07193
# [762]	train-rmse:259.87039	eval-rmse:316.07459
# [763]	train-rmse:259.76797	eval-rmse:316.03320
# [764]	train-rmse:259.71326	eval-rmse:316.02066
# [765]	train-rmse:259.71039	eval-rmse:316.01749
# [766]	train-rmse:259.65643	eval-rmse:316.03415
# [767]	train-rmse:259.58344	eval-rmse:316.00326
# [768]	train-rmse:259.52750	eval-rmse:315.98483
# [769]	train-rmse:259.52426	eval-rmse:315.98593
# [770]	train-rmse:259.51553	eval-rmse:315.98560
# [771]	train-rmse:259.48706	eval-rmse:315.96533
# [772]	train-rmse:259.44830	eval-rmse:315.93689
# [773]	train-rmse:259.42297	eval-rmse:315.91519
# [774]	train-rmse:259.41675	eval-rmse:315.91342
# [775]	train-rmse:259.38922	eval-rmse:315.89560
# [776]	train-rmse:259.36008	eval-rmse:315.88132
# [777]	train-rmse:259.32932	eval-rmse:315.86642
# [778]	train-rmse:259.30926	eval-rmse:315.86655
# [779]	train-rmse:259.27341	eval-rmse:315.85773
# [780]	train-rmse:259.24979	eval-rmse:315.84760
# [781]	train-rmse:259.16074	eval-rmse:315.79861
# [782]	train-rmse:259.09701	eval-rmse:315.84256
# [783]	train-rmse:259.07761	eval-rmse:315.83289
# [784]	train-rmse:259.06879	eval-rmse:315.82977
# [785]	train-rmse:259.03906	eval-rmse:315.82358
# [786]	train-rmse:259.03775	eval-rmse:315.82495
# [787]	train-rmse:259.03070	eval-rmse:315.82037
# [788]	train-rmse:259.02982	eval-rmse:315.82013
# [789]	train-rmse:259.00467	eval-rmse:315.80576
# [790]	train-rmse:258.99841	eval-rmse:315.80942
# [13:34:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [13:34:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "silent" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-rmse:3348.58496	eval-rmse:3341.41187
# [1]	train-rmse:3024.14404	eval-rmse:3019.72827
# [2]	train-rmse:2732.66602	eval-rmse:2731.51147
# [3]	train-rmse:2470.61231	eval-rmse:2472.92895
# [4]	train-rmse:2235.05884	eval-rmse:2241.41138
# [5]	train-rmse:2023.00610	eval-rmse:2033.52307
# [6]	train-rmse:1832.71277	eval-rmse:1848.29431
# [7]	train-rmse:1662.10278	eval-rmse:1684.13757
# [8]	train-rmse:1508.69971	eval-rmse:1537.31555
# [9]	train-rmse:1370.98572	eval-rmse:1407.00891
# [10]	train-rmse:1247.65173	eval-rmse:1291.89270
# [11]	train-rmse:1137.32190	eval-rmse:1190.67383
# [12]	train-rmse:1038.53052	eval-rmse:1102.47644
# [13]	train-rmse:950.22382	eval-rmse:1026.27380
# [14]	train-rmse:871.66492	eval-rmse:960.57983
# [15]	train-rmse:801.37976	eval-rmse:903.88971
# [16]	train-rmse:739.13538	eval-rmse:856.35876
# [17]	train-rmse:683.53992	eval-rmse:815.53839
# [18]	train-rmse:633.80658	eval-rmse:781.96692
# [19]	train-rmse:589.70966	eval-rmse:754.27820
# [20]	train-rmse:550.88342	eval-rmse:731.42352
# [21]	train-rmse:517.12256	eval-rmse:713.67554
# [22]	train-rmse:486.91138	eval-rmse:698.69800
# [23]	train-rmse:461.07138	eval-rmse:688.09271
# [24]	train-rmse:437.52460	eval-rmse:679.44110
# [25]	train-rmse:417.28152	eval-rmse:673.19043
# [26]	train-rmse:399.88269	eval-rmse:666.60052
# [27]	train-rmse:384.39951	eval-rmse:663.57898
# [28]	train-rmse:371.06854	eval-rmse:662.18884
# [29]	train-rmse:359.36395	eval-rmse:661.81812
# [30]	train-rmse:349.01947	eval-rmse:661.94281
# [31]	train-rmse:339.41571	eval-rmse:662.63355
# [32]	train-rmse:331.17895	eval-rmse:663.70758
# [33]	train-rmse:324.71420	eval-rmse:662.09070
# [34]	train-rmse:318.18216	eval-rmse:664.00226
# [35]	train-rmse:313.01224	eval-rmse:661.84564
# [36]	train-rmse:307.95026	eval-rmse:664.26764
# [37]	train-rmse:303.31168	eval-rmse:666.56073
# [38]	train-rmse:299.40811	eval-rmse:668.93280
# [39]	train-rmse:295.92438	eval-rmse:671.48895

# %% [markdown]
# ## 5. 検証

# %%
import matplotlib.pyplot as plt
prediction = model.predict(xgb.DMatrix(va_x), ntree_limit=model.best_ntree_limit) # 一番良いモデルで予測する

plt.figure(figsize=(12, 12))
plt.scatter(va_y, prediction, alpha=0.2) # 表示の関係で1000個までとする
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:104: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   UserWarning

# %%
font = {'family' : 'Meiryo'} # matplotlibのデフォルトフォントをTakaoGothicに設定
plt.rc('font', **font)
git, ax = plt.subplots(figsize=(12, 12))
xgb.plot_importance(model, max_num_features=12, height=0.8, ax=ax)
plt.show()

# %% [markdown]
# ## 6. 予測

# %%
# テストデータでの予測
pred = model.predict(xgb.DMatrix(test_x), ntree_limit=model.best_ntree_limit) # 一番良いモデルで予測する
# pred = model.predict(dtest)

# %%
pred
# Out:
# array([2564.799 , 4950.4033, 2862.658 , ..., 4254.8027, 3562.2688,
#        3620.824 ], dtype=float32)

# %%
len(pred)
# Out:
# 24812

# %%
len(test_data_1)
# Out:
# 24812

# %% [markdown]
# ## 7. データ出力

# %%
# 予測結果の結合
test_data_1["賃料/面積"] = pred

# %%
# 予測結果から賃料を算出し、int型に変換
test_data_1["賃料"] = (test_data_1["面積m2"] * test_data_1["賃料/面積"]).astype(int)

# %%
result = test_data_1[["id", "賃料"]]

# %%
result
# Out:
#           id      賃料
# 0      31471  128804
# 1      31472  103364
# 2      31473   77091
# 3      31474   62632
# 5      31476   69398
# ...      ...     ...
# 31255  62726   98193
# 31257  62728   99948
# 31258  62729   96626
# 31259  62730  163009
# 31261  62732   76689
#
# [24812 rows x 2 columns]

# %%
len(result)
# Out:
# 24812

# %%
# 除外していた重複idの賃料を戻す
test_duplicate_rentvalue = pd.read_excel("test_duplicate_rentvalue.xlsx")
result = pd.concat([result, test_duplicate_rentvalue])
result = result.sort_values("id")
len(result)
# Out:
# 31262

# %%
result
# Out:
#           id      賃料
# 0      31471  128804
# 1      31472  103364
# 2      31473   77091
# 3      31474   62632
# 0      31475   90000
# ...      ...     ...
# 31257  62728   99948
# 31258  62729   96626
# 31259  62730  163009
# 6449   62731  280000
# 31261  62732   76689
#
# [31262 rows x 2 columns]

# %%
result.to_csv("result.csv", header=False, index=False)
