# %% [markdown]
# ## 6.4.1 過学習

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（荷重減衰）の設定 =======================
weight_decay_lambda = 0 # weight decayを使用しない場合
#weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 3.グラフの描画==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.11333333333333333, test acc:0.0971
# epoch:1, train acc:0.11666666666666667, test acc:0.0925
# epoch:2, train acc:0.11333333333333333, test acc:0.0899
# epoch:3, train acc:0.09333333333333334, test acc:0.0919
# epoch:4, train acc:0.12666666666666668, test acc:0.0991
# epoch:5, train acc:0.16, test acc:0.1088
# epoch:6, train acc:0.17666666666666667, test acc:0.1301
# epoch:7, train acc:0.20333333333333334, test acc:0.147
# epoch:8, train acc:0.23666666666666666, test acc:0.1626
# epoch:9, train acc:0.2633333333333333, test acc:0.1833
# epoch:10, train acc:0.27666666666666667, test acc:0.1918
# epoch:11, train acc:0.2866666666666667, test acc:0.1987
# epoch:12, train acc:0.31333333333333335, test acc:0.2117
# epoch:13, train acc:0.32, test acc:0.2269
# epoch:14, train acc:0.3233333333333333, test acc:0.2318
# epoch:15, train acc:0.34, test acc:0.2457
# epoch:16, train acc:0.36666666666666664, test acc:0.2551
# epoch:17, train acc:0.4, test acc:0.2735
# epoch:18, train acc:0.42, test acc:0.2861
# epoch:19, train acc:0.44, test acc:0.3005
# epoch:20, train acc:0.4533333333333333, test acc:0.3144
# epoch:21, train acc:0.47, test acc:0.3319
# epoch:22, train acc:0.48, test acc:0.3396
# epoch:23, train acc:0.49, test acc:0.3478
# epoch:24, train acc:0.5133333333333333, test acc:0.3685
# epoch:25, train acc:0.49333333333333335, test acc:0.3559
# epoch:26, train acc:0.53, test acc:0.3903
# epoch:27, train acc:0.53, test acc:0.396
# epoch:28, train acc:0.53, test acc:0.3884
# epoch:29, train acc:0.55, test acc:0.4177
# epoch:30, train acc:0.5833333333333334, test acc:0.4314
# epoch:31, train acc:0.5766666666666667, test acc:0.4316
# epoch:32, train acc:0.6033333333333334, test acc:0.448
# epoch:33, train acc:0.6, test acc:0.4492
# epoch:34, train acc:0.6133333333333333, test acc:0.4611
# epoch:35, train acc:0.6366666666666667, test acc:0.4678
# epoch:36, train acc:0.64, test acc:0.4753
# epoch:37, train acc:0.6233333333333333, test acc:0.4708
# epoch:38, train acc:0.62, test acc:0.4789
# epoch:39, train acc:0.6433333333333333, test acc:0.4872
# epoch:40, train acc:0.6433333333333333, test acc:0.4896
# epoch:41, train acc:0.6366666666666667, test acc:0.4868
# epoch:42, train acc:0.6466666666666666, test acc:0.4958
# epoch:43, train acc:0.6566666666666666, test acc:0.5035
# epoch:44, train acc:0.6733333333333333, test acc:0.5043
# epoch:45, train acc:0.6966666666666667, test acc:0.5191
# epoch:46, train acc:0.6933333333333334, test acc:0.5243
# epoch:47, train acc:0.69, test acc:0.5208
# epoch:48, train acc:0.6966666666666667, test acc:0.5225
# epoch:49, train acc:0.7166666666666667, test acc:0.5303
# epoch:50, train acc:0.7166666666666667, test acc:0.5314
# epoch:51, train acc:0.74, test acc:0.5427
# epoch:52, train acc:0.7433333333333333, test acc:0.5381
# epoch:53, train acc:0.74, test acc:0.5433
# epoch:54, train acc:0.7466666666666667, test acc:0.5393
# epoch:55, train acc:0.7666666666666667, test acc:0.5557
# epoch:56, train acc:0.7733333333333333, test acc:0.5803
# epoch:57, train acc:0.7666666666666667, test acc:0.5684
# epoch:58, train acc:0.77, test acc:0.5778
# epoch:59, train acc:0.7933333333333333, test acc:0.5974
# epoch:60, train acc:0.7966666666666666, test acc:0.5866
# epoch:61, train acc:0.79, test acc:0.5884
# epoch:62, train acc:0.8033333333333333, test acc:0.5912
# epoch:63, train acc:0.8066666666666666, test acc:0.5991
# epoch:64, train acc:0.8233333333333334, test acc:0.6081
# epoch:65, train acc:0.82, test acc:0.6256
# epoch:66, train acc:0.83, test acc:0.6155
# epoch:67, train acc:0.81, test acc:0.6052
# epoch:68, train acc:0.81, test acc:0.6101
# epoch:69, train acc:0.8366666666666667, test acc:0.6255
# epoch:70, train acc:0.83, test acc:0.6055
# epoch:71, train acc:0.8333333333333334, test acc:0.6279
# epoch:72, train acc:0.8366666666666667, test acc:0.6151
# epoch:73, train acc:0.8433333333333334, test acc:0.624
# epoch:74, train acc:0.8633333333333333, test acc:0.629
# epoch:75, train acc:0.85, test acc:0.6258
# epoch:76, train acc:0.83, test acc:0.6122
# epoch:77, train acc:0.8566666666666667, test acc:0.629
# epoch:78, train acc:0.8666666666666667, test acc:0.6423
# epoch:79, train acc:0.8566666666666667, test acc:0.6331
# epoch:80, train acc:0.8533333333333334, test acc:0.6294
# epoch:81, train acc:0.8533333333333334, test acc:0.6295
# epoch:82, train acc:0.8666666666666667, test acc:0.6336
# epoch:83, train acc:0.8666666666666667, test acc:0.6335
# epoch:84, train acc:0.86, test acc:0.6585
# epoch:85, train acc:0.8633333333333333, test acc:0.6399
# epoch:86, train acc:0.84, test acc:0.6426
# epoch:87, train acc:0.8566666666666667, test acc:0.6422
# epoch:88, train acc:0.8666666666666667, test acc:0.65
# epoch:89, train acc:0.8733333333333333, test acc:0.6548
# epoch:90, train acc:0.8766666666666667, test acc:0.6489
# epoch:91, train acc:0.87, test acc:0.6415
# epoch:92, train acc:0.8666666666666667, test acc:0.6477
# epoch:93, train acc:0.87, test acc:0.6437
# epoch:94, train acc:0.8666666666666667, test acc:0.6601
# epoch:95, train acc:0.8833333333333333, test acc:0.6524
# epoch:96, train acc:0.88, test acc:0.6587
# epoch:97, train acc:0.86, test acc:0.647
# epoch:98, train acc:0.8766666666666667, test acc:0.6662
# epoch:99, train acc:0.8733333333333333, test acc:0.6565
# epoch:100, train acc:0.8866666666666667, test acc:0.6661
# epoch:101, train acc:0.88, test acc:0.6667
# epoch:102, train acc:0.8866666666666667, test acc:0.6623
# epoch:103, train acc:0.88, test acc:0.664
# epoch:104, train acc:0.8733333333333333, test acc:0.6626
# epoch:105, train acc:0.8833333333333333, test acc:0.6652
# epoch:106, train acc:0.88, test acc:0.6667
# epoch:107, train acc:0.8833333333333333, test acc:0.6687
# epoch:108, train acc:0.8833333333333333, test acc:0.6477
# epoch:109, train acc:0.8766666666666667, test acc:0.6574
# epoch:110, train acc:0.8766666666666667, test acc:0.6624
# epoch:111, train acc:0.8833333333333333, test acc:0.6582
# epoch:112, train acc:0.88, test acc:0.6706
# epoch:113, train acc:0.8833333333333333, test acc:0.673
# epoch:114, train acc:0.9, test acc:0.6779
# epoch:115, train acc:0.9033333333333333, test acc:0.6761
# epoch:116, train acc:0.8866666666666667, test acc:0.6778
# epoch:117, train acc:0.89, test acc:0.6714
# epoch:118, train acc:0.8866666666666667, test acc:0.6788
# epoch:119, train acc:0.8933333333333333, test acc:0.6737
# epoch:120, train acc:0.87, test acc:0.6721
# epoch:121, train acc:0.8833333333333333, test acc:0.6619
# epoch:122, train acc:0.8833333333333333, test acc:0.669
# epoch:123, train acc:0.8966666666666666, test acc:0.6696
# epoch:124, train acc:0.8966666666666666, test acc:0.6722
# epoch:125, train acc:0.8933333333333333, test acc:0.6722
# epoch:126, train acc:0.89, test acc:0.678
# epoch:127, train acc:0.8966666666666666, test acc:0.6641
# epoch:128, train acc:0.8866666666666667, test acc:0.6704
# epoch:129, train acc:0.8966666666666666, test acc:0.6764
# epoch:130, train acc:0.8966666666666666, test acc:0.6734
# epoch:131, train acc:0.8966666666666666, test acc:0.6639
# epoch:132, train acc:0.9133333333333333, test acc:0.6728
# epoch:133, train acc:0.91, test acc:0.674
# epoch:134, train acc:0.9, test acc:0.6781
# epoch:135, train acc:0.8966666666666666, test acc:0.6731
# epoch:136, train acc:0.91, test acc:0.6795
# epoch:137, train acc:0.9033333333333333, test acc:0.668
# epoch:138, train acc:0.9, test acc:0.6755
# epoch:139, train acc:0.9066666666666666, test acc:0.684
# epoch:140, train acc:0.9, test acc:0.6787
# epoch:141, train acc:0.9, test acc:0.6853
# epoch:142, train acc:0.9, test acc:0.6799
# epoch:143, train acc:0.9066666666666666, test acc:0.675
# epoch:144, train acc:0.9066666666666666, test acc:0.6767
# epoch:145, train acc:0.9, test acc:0.6893
# epoch:146, train acc:0.9133333333333333, test acc:0.68
# epoch:147, train acc:0.8966666666666666, test acc:0.6837
# epoch:148, train acc:0.9066666666666666, test acc:0.6824
# epoch:149, train acc:0.9133333333333333, test acc:0.6871
# epoch:150, train acc:0.91, test acc:0.6839
# epoch:151, train acc:0.9066666666666666, test acc:0.6791
# epoch:152, train acc:0.9166666666666666, test acc:0.6877
# epoch:153, train acc:0.8966666666666666, test acc:0.6869
# epoch:154, train acc:0.91, test acc:0.6784
# epoch:155, train acc:0.91, test acc:0.6762
# epoch:156, train acc:0.9066666666666666, test acc:0.676
# epoch:157, train acc:0.9133333333333333, test acc:0.69
# epoch:158, train acc:0.91, test acc:0.6904
# epoch:159, train acc:0.9166666666666666, test acc:0.6852
# epoch:160, train acc:0.9133333333333333, test acc:0.6843
# epoch:161, train acc:0.9166666666666666, test acc:0.6849
# epoch:162, train acc:0.91, test acc:0.6802
# epoch:163, train acc:0.9133333333333333, test acc:0.6809
# epoch:164, train acc:0.91, test acc:0.6864
# epoch:165, train acc:0.9133333333333333, test acc:0.6846
# epoch:166, train acc:0.9066666666666666, test acc:0.6864
# epoch:167, train acc:0.92, test acc:0.6941
# epoch:168, train acc:0.9033333333333333, test acc:0.6891
# epoch:169, train acc:0.9166666666666666, test acc:0.6883
# epoch:170, train acc:0.9233333333333333, test acc:0.6904
# epoch:171, train acc:0.9133333333333333, test acc:0.6869
# epoch:172, train acc:0.91, test acc:0.688
# epoch:173, train acc:0.9133333333333333, test acc:0.6835
# epoch:174, train acc:0.92, test acc:0.6808
# epoch:175, train acc:0.91, test acc:0.6834
# epoch:176, train acc:0.9133333333333333, test acc:0.6873
# epoch:177, train acc:0.91, test acc:0.685
# epoch:178, train acc:0.91, test acc:0.6768
# epoch:179, train acc:0.9233333333333333, test acc:0.6898
# epoch:180, train acc:0.91, test acc:0.6853
# epoch:181, train acc:0.91, test acc:0.6893
# epoch:182, train acc:0.9133333333333333, test acc:0.6879
# epoch:183, train acc:0.9133333333333333, test acc:0.6866
# epoch:184, train acc:0.9133333333333333, test acc:0.677
# epoch:185, train acc:0.92, test acc:0.6867
# epoch:186, train acc:0.92, test acc:0.6948
# epoch:187, train acc:0.92, test acc:0.6906
# epoch:188, train acc:0.92, test acc:0.6926
# epoch:189, train acc:0.9133333333333333, test acc:0.6946
# epoch:190, train acc:0.9133333333333333, test acc:0.6926
# epoch:191, train acc:0.9133333333333333, test acc:0.683
# epoch:192, train acc:0.9133333333333333, test acc:0.68
# epoch:193, train acc:0.9166666666666666, test acc:0.6861
# epoch:194, train acc:0.9233333333333333, test acc:0.6948
# epoch:195, train acc:0.9133333333333333, test acc:0.6909
# epoch:196, train acc:0.9166666666666666, test acc:0.6851
# epoch:197, train acc:0.92, test acc:0.6825
# epoch:198, train acc:0.9066666666666666, test acc:0.6843
# epoch:199, train acc:0.9066666666666666, test acc:0.6871
# epoch:200, train acc:0.9066666666666666, test acc:0.6794
