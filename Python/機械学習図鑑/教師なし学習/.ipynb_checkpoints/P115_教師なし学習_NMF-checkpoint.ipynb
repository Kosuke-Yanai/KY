# %% [markdown]
# NMF実行サンプルコード

# %%
from sklearn.decomposition import NMF
from sklearn.datasets.samples_generator import make_blobs

centers = [[5, 10, 5], [10, 4, 10], [6, 8, 8]]
V, _ = make_blobs(centers=centers)

n_components = 2
model = NMF(n_components=n_components)
model.fit(V)

W = model.transform(V) #分解後の行列
H = model.components_
print(W)
print(H)
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# [[0.91371394 0.89718536]
#  [0.71015436 1.09352935]
#  [1.22943077 0.1577147 ]
#  [0.81475042 0.8618286 ]
#  [0.69885783 0.89662785]
#  [1.30302481 0.30942835]
#  [1.32598592 0.23326253]
#  [0.62720788 0.93637833]
#  [1.33461764 0.15847776]
#  [0.98369327 0.7801328 ]
#  [0.87425361 0.75140315]
#  [1.06598949 0.81748576]
#  [0.82025564 0.8820512 ]
#  [0.66869034 1.034417  ]
#  [0.62458563 0.86140504]
#  [1.31011782 0.00306936]
#  [1.45776277 0.17657194]
#  [0.79555345 0.88131485]
#  [0.81435754 0.71348098]
#  [1.25754208 0.55043871]
#  [1.33849292 0.13916861]
#  [1.19338918 0.25861613]
#  [0.43700673 0.93932206]
#  [1.22314605 0.36566039]
#  [0.549698   1.01010133]
#  [1.03058139 0.60200657]
#  [1.13389169 0.11961654]
#  [0.61970618 0.90974939]
#  [0.72232089 0.65188067]
#  [1.39945989 0.19118567]
#  [1.29253994 0.2256332 ]
#  [0.91642132 0.61315722]
#  [0.7581628  0.64429655]
#  [0.98223852 0.82048473]
#  [1.21272601 0.31710472]
#  [0.65076192 0.97319107]
#  [0.83387738 0.56454444]
#  [1.31779612 0.26385571]
#  [1.10872441 0.75647668]
#  [0.96235853 0.72610188]
#  [1.51675108 0.10246914]
#  [1.29053948 0.38982027]
#  [0.63030852 0.95836715]
#  [1.31818039 0.1638925 ]
#  [0.9605712  0.66144641]
#  [1.09036126 0.68979129]
#  [0.86295448 0.78408431]
#  [1.28112029 0.35529771]
#  [0.94395568 0.65369378]
#  [0.75887816 1.21620587]
#  [0.69833079 0.90847972]
#  [0.92524655 0.62508154]
#  [1.32258951 0.20623286]
#  [1.42723723 0.        ]
#  [1.42083538 0.1273585 ]
#  [0.66768771 0.88506212]
#  [0.72876526 1.1623344 ]
#  [1.28995247 0.22454507]
#  [1.08640685 0.89827061]
#  [0.82664901 0.72229682]
#  [0.61426055 0.97877502]
#  [1.07110713 0.85469466]
#  [1.39118575 0.13941969]
#  [0.69351108 0.98352569]
#  [1.33870889 0.32750048]
#  [0.58169857 0.88545378]
#  [0.97688688 0.61459323]
#  [1.04920876 0.70787303]
#  [0.92816133 0.78457258]
#  [0.88066839 0.99741115]
#  [0.6823676  0.98844882]
#  [0.49859443 1.09422404]
#  [1.17260761 0.12245703]
#  [0.59674405 0.84747962]
#  [1.38143111 0.41973817]
#  [0.85690209 1.02573342]
#  [0.68286942 0.93118051]
#  [0.86922823 0.78993702]
#  [0.91352527 0.75980211]
#  [0.966732   0.87715802]
#  [0.70337523 1.09056003]
#  [0.61223348 1.01041366]
#  [1.10948596 0.66795055]
#  [0.72057108 1.01760952]
#  [1.46826692 0.28184995]
#  [0.62469861 0.95609661]
#  [0.7524207  0.89502759]
#  [1.10416374 0.6847536 ]
#  [1.35994209 0.23907399]
#  [0.54896557 1.03426164]
#  [0.55854298 1.14844689]
#  [1.3376196  0.09267843]
#  [1.31577753 0.2899213 ]
#  [0.97315437 0.64356845]
#  [1.33574848 0.17727152]
#  [0.57392186 0.98997161]
#  [0.5591182  0.97057741]
#  [0.4540208  0.92639941]
#  [1.57912195 0.16868166]
#  [1.31112112 0.33297403]]
# [[7.15001161 1.57276145 7.86359796]
#  [0.01320492 9.12087982 0.        ]]

# %% [markdown]
# データセットの描画
# 3次元グラフの作成順序
#  1. figureで2次元の図を生成する
#  2. その後，Axes3D関数で3次元にする

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure()
ax = Axes3D(fig)

V_x_0 = V[_==0,0:1]
V_y_0 = V[_==0,1:2]
V_z_0 = V[_==0,2:3]

ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x, y)")

ax.plot_wireframe(V_x_0, V_y_0, V_z_0)
ax.plot(X,Y,Z,marker="o",linestyle='None')
plt.show()

# %%
V_x = V[_==0,0:1]
V_x
# Out:
# array([[5.40353625],
#        [4.77383684],
#        [6.45942788],
#        [5.77329154],
#        [3.93461914],
#        [4.25051278],
#        [5.26757386],
#        [3.45090021],
#        [5.06878513],
#        [4.77978172],
#        [5.53919516],
#        [4.13820474],
#        [4.82439441],
#        [4.87815461],
#        [5.19651316],
#        [5.12842959],
#        [5.85219509],
#        [5.70225295],
#        [5.45215968],
#        [4.8768969 ],
#        [5.09253052],
#        [4.86057713],
#        [3.84636661],
#        [7.43180706],
#        [6.15928226],
#        [6.08603064],
#        [4.52505048],
#        [5.17821043],
#        [3.43938436],
#        [4.47736518],
#        [5.7965918 ],
#        [4.13002901],
#        [5.90251673],
#        [3.73186563]])
